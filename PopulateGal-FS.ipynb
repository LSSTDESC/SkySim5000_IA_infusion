# %%
# By Joachim Harnois-Deraps, with inputs from Ben Giblin on the galaxy populatio algorithm, 
# and Nan Li on some lensing subroutines 
# Code illustrating extraction of shear from Mira Titan/SkySim5000 healpix maps

import numpy as np
import healpy as hp
import random
import input
import matplotlib.pyplot as plt
import h5py
from astropy import units as u
from astropy.cosmology import FlatLambdaCDM
from astropy.cosmology import z_at_value


SkySim=False
HACCY1=False
FS = True

#Choose Nz:
#SRD:
nz_filename='/global/homes/j/jharno//RR2_v2_Nz_WL_C2020_sel_pv_rebinned_100_bins_cut_z_3_normalized.dat'
path_out = '/pscratch/sd/j/jharno/FS/'


#Stage-IV_Euclid"
#nz_filename='./Euclid_dndz_fu08_bin1-5.dat'

# the number of galaxies per square arcminute to extract
gpam = 0.6
#gpam = 2.6    #LSST, per tomo bin
#gpam = 1.493  #KiDS tomo4
#gpam = 1.830  #KiDS tomo3
#gpam = 1.856  #KiDS tomo2
#gpam = 2.354  #KiDS tomo1

print('assigning %f gal/arcmin**2' % gpam)

# the number of galaxies to extract in the octant
ngal = int(gpam * (4.*np.pi/8.)*(180./np.pi)**2. *3600.)
print('for a total of %i galaxies' % ngal)

# The NSIDE value of the shear and weight maps
if(FS):
    nside = 1024
if(SkySim):
    nside = 8192
if(HACCY1):
    #nside = 4096
    nside = 8192
    seed=0 #seed = 0,1,2
    nshells=51 #nshells=19,26, 27,34, 50, 51,101,106
    IC="150_3"      #IC=150,195, 150_2, 150_3

npix = 12*nside**2
pix_size = np.sqrt(4.*np.pi*(180./np.pi*60)**2/npix)
print('pixel size of shear maps is %f arcmin per side' % pix_size)

ncosmo = FlatLambdaCDM(H0=66.99998481005214,Om0=0.328999999, Ob0=0.049000)


def IndexToDeclRa(index):
        theta,phi=hp.pixelfunc.pix2ang(nside,index,nest=False)
        return np.degrees(np.pi/2. - theta),np.degrees(phi)
    
def GetNz(nz_filename,tomobin):
        print("Reading in N(z) from tomobin  %d" % tomobin)
        data = np.loadtxt(nz_filename, usecols=(0,tomobin))
        z_array = data[:,0]
        pdz = data[:,1]
        dz = z_array[41] - z_array[40]
        n_zbins = np.size(pdz)

        # Normalise:
        pdz = pdz/sum(pdz)/dz
        print("Check normalisation: sum n(z) dz = ",sum(pdz)*dz)
        print("Mean redshift = ", np.dot(pdz,z_array)*dz)
        return n_zbins,z_array, pdz,dz
    
def AssignRedshifts(n_zbins,pdz,dz):

        #construct cumulative distribution
        cumul_dist = np.zeros(n_zbins)

        for z_bin in range(0,n_zbins):
            cumul_dist[z_bin] = sum(pdz[0:z_bin+1])/sum(pdz)
            #print(z_array[z_bin], pdz[z_bin], cumul_dist[z_bin])

        print('Got cumul dist')
        
        #--------------------------------https://github.com/NiallJeffrey/BornRaytrace/tree/main
        #draw the galaxies from this n(z) (This routine may take a few seconds to execute)
        spec_z = np.zeros(ngal)

        for gal in range(0,ngal):
            gal_bin = 0
            ran = random.uniform(0, 1)
            for z_bin in range(0,n_zbins):
                #print ran, cumul_dist[z_bin]
                if ran < cumul_dist[z_bin]:
                    gal_bin = z_bin
                    break
            
            #randomize distribution within that bin
            ran2 = random.uniform(0,1)*dz
            spec_z[gal] = z_array[gal_bin]+ran2
            #print( gal, gal_bin, z_array[gal_bin], spec_z[gal],z_array[gal_bin+1])


        print('Assigned redshift to these galaxies')
        print('-----------------------------------')
        return spec_z
    
def PlotNz(spec_z,z_array,dz,pdz,tomobin):
    
        # the histogram of the data
        n, bins, patches = plt.hist(spec_z, 60, density=True, facecolor='g',alpha=0.75)
        plt.xlabel('z')
        plt.ylabel('n(z)')
        #plt.text(60, .025, r'tomobin 1')
        plt.grid(True)

        plt.plot(z_array+dz/2, pdz)
        if tomobin==1: 
            plt.xlim(0, 0.75)
            plt.ylim(0, 4.0)
        elif tomobin==2: 
            plt.xlim(0.45, 0.85)
            plt.ylim(0, 5.0)
        elif tomobin==3: 
            plt.xlim(0.65, 1.05)
            plt.ylim(0, 5.0)
        elif tomobin==4: 
            plt.xlim(0.95, 1.45)
            plt.ylim(0, 5.0)
        elif tomobin==5: 
            plt.xlim(1.3, 3.10)
            plt.ylim(0, 5.0)

        plt.show()
# Out:
# assigning 0.600000 gal/arcmin**2
# for a total of 11138299 galaxies
# pixel size of shear maps is 3.435486 arcmin per side

# %%
def PopulateHACCY1(spec_z,tomobin,gpam,IC,seed,nshells):

        import healsparse
        import random
        import os

        nside_c = 32
        
        #IC=195
        #path = '/global/cscratch1/sd/xuod/HOS_sims/L845/HACC'+str(IC)+'/'
        #path = '/global/cfs/cdirs/lsst/groups/WL/projects/hos-tt/sims/L845/HACC'+str(IC)+'/'
        #path = '/pscratch/sd/x/xuod/HOS_Sims/HACC'+str(IC)+'/'
        #path = '/pscratch/sd/j/jmena/HOS_Sims/HACC'+str(IC)+'/'
        path = '/global/cfs/cdirs/lsst/groups/WL/projects/wl-massmap/IA-infusion/BCM/'
        #path = '../../HACC-Y1/shear/V0/IC150/seed0/'
        #nshells = 27
        what1='gamma1'
        what2='gamma2'
        nzs='kappa_zsnapshots'
        dmo=True
        BCM_model='dmo';BCM_model_Bera='/Mc/1e14/'
        #BCM_model='dmb';BCM_model_Bera='/Mc/1e14/'
        #BCM_model='dmb_Mc2e14';BCM_model_Bera='/Mc/2e14/'
        #BCM_model='dmb_Mc4e14';BCM_model_Bera='/Mc/4e14/'
        #BCM_model='dmb_Mc2.5e13';BCM_model_Bera='/Mc/2.5e13/'
        #BCM_model='dmb_Mc5e13';BCM_model_Bera='/Mc/5e13/'
        #BCM_model='dmb_theta_ej_2';BCM_model_Bera='theta_ej/2/
        #BCM_model='dmb_theta_ej_3';BCM_model_Bera='theta_ej/3/
        #BCM_model='dmb_theta_ej_5';BCM_model_Bera='theta_ej/5/
        #BCM_model='dmb_theta_ej_6';BCM_model_Bera='theta_ej/6/

        #find galaxies between shear planes i and j, load the maps, interpolate, loop over next maps

        # Selection population option:
        # 1 = randomly choose pixels from the unmasked section of the map
        # 2 = randomly generate angular coords from the unmasked octant (more accurate than OPTION 1)
        # 3 = load mass sheet and populate the galaxies following a linear biasing scheme
        OPTION=2
        b_TA = 1.0
        
        #zfile=np.loadtxt("z2ts_HACCY1_"+str(nshells)+".txt")
        

        ##tmpfile = np.load(path+"/shells_z"+str(nshells)+"_subsampleauto_groupiso/shell_hacc_seed0_shell_info.npy")
        #tmpfile = np.load(path+"/shells_z"+str(nshells)+"_nosubsample_groupisoshell_hacc_seed0_shell_info.npy")
        #tmpfile = np.load(path+"/shells_z"+str(nshells)+"_subsampleclmax100_groupiso/shell_hacc_seed0_shell_info.npy")
        #tmpfile = np.load(path+"/shells_z"+str(nshells)+"_subsampleclmax100_groupiso/shell_hacc_seed0_shell_info.npy")
        tmpfile = np.load("/pscratch/sd/j/jmena/HOS_Sims/HACC150_3/shells_z"+str(nshells)+"_subsampledensitymax1.5_nside8192/shell_hacc_seed0_shell_info.npy")
        zfile = np.zeros([nshells,5])
        for i in np.arange(nshells):
            #print(tmpfile[i][0], tmpfile[i][1], tmpfile[i][2], tmpfile[i][3], tmpfile[i][4])
            zfile[i,0:5]= [tmpfile[i][0], tmpfile[i][1], tmpfile[i][2], tmpfile[i][3], tmpfile[i][4]]
            
        #snaplist = zfile[1:107,1].astype(int)
        shell_list=np.flip(zfile[:,0])
        z_list=np.flip(zfile[:,1]) 
        z_list_front=np.flip(zfile[:,2])
        z_list_back=np.flip(zfile[:,3])
        n_slices = np.size(z_list)
        #print(zfile)
        #print(z_list)

        ngal_cur = np.zeros(n_slices, dtype=int)

        ngal_analyzed = 0
        weight_flag = 0
        recycle_map_flag = 0

        # Loop over all planes, starting from high redshift towards z=0
        # If these maps are Nested ordered, need to ring-order them.

        #for plane in range(37,n_slices):
        #for plane in range(0,37):
        for plane in range(0,n_slices):

            print('starting analysis of plane %i' % plane)

            z_back = z_list_back[plane]
            z_front = z_list_front[plane]

            print('z_lo - z_mid -  z_hi =',   z_front, z_list[plane], z_back)
            gal_cur = np.where(np.logical_and(spec_z>z_front, spec_z<=z_back))
            ngal_cur[plane] = np.size(gal_cur)
            if ngal_cur[plane] == 0:
                print('no galaxies here, loop to next plane')
            else:
                print('found %s galaxies between z=%f and z=%f' % (ngal_cur[plane], z_front, z_back))
                ngal_analyzed = ngal_analyzed+ngal_cur[plane]
                #
                if ngal_cur[plane-1] >0:
                    print("Found consecutive planes not empty, recycle planes to save IO:")
                    recycle_map_flag = 1
                    # Uncomment the above to enable recycling

                #Interpolate from shear maps onto redshift of the halo:
                #! dz1 (dz2) is fractional distance to plane behind (in front)
                #
                dz1 = z_back - spec_z[gal_cur]
                if plane == n_slices -1:
                    dz2 = spec_z[gal_cur]
                else: 
                    dz2 = spec_z[gal_cur] - z_front
                #
                dz1 = dz1/(dz1 + dz2)
                dz2 = 1. - dz1
                #
                #  ishell=0 -> z=0 in Cyrille's maps, contrary to the naming from the HACC snapshots.
                ishell = int(shell_list[plane]) 

                #print(z_front, z_back, spec_z[gal_cur], dz1, dz2)


                if weight_flag == 0:
                    print('reading weight file')
                    weight_flag = 1
                    print("Reading in weight map for HACC-Y1")
                    hpmap_weight = hp.fitsfunc.read_map('../../FullSky_weight.fits', field=0,nest=False, partial=False, hdu=1, h=False, verbose=True, memmap=True)
                    #hpmap_weight = hp.fitsfunc.read_map('../../FullSky_weight_4096.fits', field=0,nest=False, partial=False, hdu=1, h=False, verbose=True, memmap=True)
                    #
                    # masking - not really necessary here, but just in case it is useful for something else.
                    unmask = np.where(hpmap_weight > 0)[0]
                    #
                if recycle_map_flag==0:
                    print("Reading in shear 1 back (zs = %f)" % z_back)
                    print("Reading in shear 2 back (zs = %f)" % z_back)
                    fname1 = path+BCM_model+"/shear/"+str("{:5.4f}".format(z_back))+"gamma1.npy"
                    fname2 = path+BCM_model+"/shear/"+str("{:5.4f}".format(z_back))+"gamma2.npy"

                    #HACC:
                    # a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_subsampleauto_groupiso/{nzs}/kappa_hacc_seed{seed}_nside4096_gamma1_imap{ishell}.fits'))
                    # a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_nosubsample_groupiso/{nzs}/kappa_hacc_seed{seed}_nside4096_gamma1_imap{ishell}.fits'))
                    # a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_subsampleclmax100_groupiso/{nzs}/kappa_hacc_seed{seed}_nside4096_gamma1_imap{ishell}.fits'))
                    # a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_nosubsample_nside8192/{nzs}/kappa_hacc_seed{seed}_nside8192_gamma1_imap{ishell}.fits'))
                    #a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_subsampledensitymax1.5_nside8192/{nzs}/kappa_hacc_seed{seed}_nside8192_gamma1_imap{ishell}.fits'))
                    #hpmap_g1_back = a.generate_healpix_map()
                    #hpmap_g1_back = hp.pixelfunc.reorder(hpmap_g1_back, n2r=True)
                    
                    #BCM: 
                    hpmap_g1_back = np.load(fname1)

                    
                    print("loaded gamma1")

                        
                    #HACC:
                    #a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_subsampleauto_groupiso/{nzs}/kappa_hacc_seed{seed}_nside4096_gamma2_imap{ishell}.fits'))
                    #a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_nosubsample_groupiso/{nzs}/kappa_hacc_seed{seed}_nside4096_gamma2_imap{ishell}.fits'))
                    #a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_subsampleclmax100_groupiso/{nzs}/kappa_hacc_seed{seed}_nside4096_gamma2_imap{ishell}.fits'))
                    #a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_nosubsample_nside8192/{nzs}/kappa_hacc_seed{seed}_nside8192_gamma2_imap{ishell}.fits'))
                    #a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_subsampledensitymax1.5_nside8192/{nzs}/kappa_hacc_seed{seed}_nside8192_gamma2_imap{ishell}.fits'))
                    #hpmap_g2_back = a.generate_healpix_map()
                    #hpmap_g2_back = hp.pixelfunc.reorder(hpmap_g2_back, n2r=True)
                                       
                    #BCM: 
                    hpmap_g2_back = np.load(fname2)

                    
                    print("loaded gamma2")                                    

                    #a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_subsampleauto_groupiso/{nzs}/kappa_hacc_nz{plane}_nside4096_seed{seed}.fits'))
                    #hpmap_kappa_back = a.generate_healpix_map()
                    #print("loaded kappa")                                    

                    #hp.orthview(hpmap_g1_back**2 + hpmap_g2_back**2, rot=(35, 20),half_sky=True, min=-0.1, max=0.1, title=None)
                    #hp.graticule()
                    #hp.orthview(hpmap_kappa_back, rot=(35, 20),half_sky=True, min=-0.1, max=0.1, title=None)
                    #hp.graticule()
                    #hp.mollview(hpmap_g1_back, nest=True)
                    #hp.mollview(hpmap_g2_back, nest=True)
                    #plt.show()

                else:
                    print("Recycling map to reduce IO:, zs = %f was already loaded, now used as back plane" % z_back)
                    hpmap_g1_back= hpmap_g1_front
                    hpmap_g2_back= hpmap_g2_front
                    #hpmap_kappa_back= hpmap_kappa_front

                    recycle_map_flag = 0
                #
                print("Reading in shear 1/2 front (zs = %f)" % z_front)

                if z_front==0:
                    hpmap_g1_front = hpmap_g1_back - hpmap_g1_back
                    hpmap_g2_front = hpmap_g2_back - hpmap_g2_back
                    #hpmap_kappa_front = hpmap_kappa_back - hpmap_kappa_back

                else:
                    fname1 = path+BCM_model+"/shear/"+str("{:5.4f}".format(z_front))+"gamma1.npy"
                    fname2 = path+BCM_model+"/shear/"+str("{:5.4f}".format(z_front))+"gamma2.npy"

                    #HACC:
                    #a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_subsampleauto_groupiso/{nzs}/kappa_hacc_seed{seed}_nside4096_gamma1_imap{ishell - 1}.fits'))
                    #a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_subsampleclmax100_groupiso/{nzs}/kappa_hacc_seed{seed}_nside4096_gamma1_imap{ishell - 1}.fits'))
                    #a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_nosubsample_groupiso/{nzs}/kappa_hacc_seed{seed}_nside4096_gamma1_imap{ishell - 1}.fits'))
                    #a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_nosubsample_nside8192/{nzs}/kappa_hacc_seed{seed}_nside8192_gamma1_imap{ishell-1}.fits'))
                    #a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_subsampledensitymax1.5_nside8192/{nzs}/kappa_hacc_seed{seed}_nside8192_gamma1_imap{ishell-1}.fits'))
                    #hpmap_g1_front = a.generate_healpix_map()
                    #hpmap_g1_front = hp.pixelfunc.reorder(hpmap_g1_front, n2r=True)

                    #BCM:
                    hpmap_g1_front=np.load(fname1)
                    
                    print("loaded gamma1")

                    #HACC:
                    #a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_subsampleauto_groupiso/{nzs}/kappa_hacc_seed{seed}_nside4096_gamma2_imap{ishell - 1}.fits'))
                    #a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_subsampleclmax100_groupiso/{nzs}/kappa_hacc_seed{seed}_nside4096_gamma2_imap{ishell - 1}.fits'))
                    #a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_nosubsample_groupiso/{nzs}/kappa_hacc_seed{seed}_nside4096_gamma2_imap{ishell - 1}.fits'))
                    #a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_nosubsample_nside8192/{nzs}/kappa_hacc_seed{seed}_nside8192_gamma2_imap{ishell-1}.fits'))
                    #a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_subsampledensitymax1.5_nside8192/{nzs}/kappa_hacc_seed{seed}_nside8192_gamma2_imap{ishell-1}.fits'))
                    #hpmap_g2_front = a.generate_healpix_map()
                    #hpmap_g2_front = hp.pixelfunc.reorder(hpmap_g2_front, n2r=True)
                    
                    #BCM:
                    hpmap_g2_front=np.load(fname2)

                    print("loaded gamma2")                                    

                    #a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_subsampleauto_groupiso/{nzs}/kappa_hacc_nz{plane+1}_nside4096_seed{seed}.fits'))
                    #hpmap_kappa_front = a.generate_healpix_map()
                    #print("loaded kappa")                                    


                # Got shear and kappa maps 
                #hp.mollview(hpmap_g1_back, nest=False)
                #plt.show()
                #hp.mollview(hpmap_g2_back, nest=False)
                #plt.show()              
                #hp.mollview(hpmap_g1_front, nest=False)
                #plt.show()
                #hp.mollview(hpmap_g2_front, nest=False)
                #plt.show()
                #hp.mollview(hpmap_weight, nest=False)
                #plt.show()
              
                
                


                #-------------
                if(OPTION==1):
                    # OPTION 1:
                    # randomly choose pixels from the unmasked section of the map
                    print('Getting the indicies for %s random unmasked galaxies in Mira Titan' %ngal_cur[plane])
                    #idx = np.random.choice(unmask, int(ngal_cur[plane]))
                    #print idx
                    #
                    # get the ra and dec of these pixels
                    #dec,ra= IndexToDeclRa( idx )
                    #
                    # get the shear maps at these pixels
                    #shear1_pix_front = hpmap_g1_front[idx]
                    #shear2_pix_front = hpmap_g2_front[idx]
                    #shear1_pix_back = hpmap_g1_back[idx]
                    #shear2_pix_back = hpmap_g2_back[idx]
                    #
                    #print shear1_pix_front, shear1_pix_back, dz1, dz2, shear1_pix_front*dz1 + shear1_pix_back*dz2
                    #print shear2_pix_front, shear2_pix_back, dz1, dz2, shear2_pix_front*dz1 + shear2_pix_back*dz2
                    #
                    #
                    #np.savetxt('./MyProject/MT_nz_delta05_LSST_lmax20000_%sGpAM_zfront%s_z_back%s.asc'%(gpam,z_front, z_back), np.c_[ra, dec, shear1_pix_front*dz1 + shear1_pix_back*dz2, shear2_pix_front*dz1 + shear2_pix_back*dz2,spec_z[gal_cur]])
                    #np.savetxt('./MyProject/MT_nz_LSST_lmax20000_%sGpAM_zfront%s_z_back%s_recycle.asc'%(gpam,z_front, z_back), np.c_[ra, dec, shear1_pix_front*dz1 + shear1_pix_back*dz2, shear2_pix_front*dz1 + shear2_pix_back*dz2, hpmap_weight[idx],spec_z[gal_cur]])
                    #np.savetxt('./MyProject/MT_nz_LSST_lmax20000_%sGpAM_zfront%s_z_back%s_dz_flip.asc'%(gpam,z_front, z_back), np.c_[ra, dec, shear1_pix_front*dz2 + shear1_pix_back*dz1, shear2_pix_front*dz2 + shear2_pix_back*dz1,hpmap_weight[idx] spec_z[gal_cur]])
                    #np.savetxt('./MyProject/MT_nz_LSST_lmax5000%sGpAM_zfront%s_z_back%s.asc'%(gpam,z_front, z_back), np.c_[ra, dec, shear1_pix_front*dz1 + shear1_pix_back*dz2, shear2_pix_front*dz1 + shear2_pix_back*dz2,spec_z[gal_cur]])
                    #np.savetxt('./MyProject/MT_nz_KiDS_01_09_lmax32768%sGpAM_nside%s.asc'%(gpam,nside), np.c_[ra, dec, hpmap_g1[idx], hpmap_g2[idx], hpmap_weight[idx] ])

                    #-------------
                elif(OPTION==2):
                    # OPTION 2:
                    # randomly generate angular coords from the unmasked octant, and use healpy interpolation
                    # function to get the shear at these locations
                    dec,ra = IndexToDeclRa( unmask )
                    ra_rand = np.random.uniform( np.min(ra), np.max(ra), ngal_cur[plane])
                    #
                    # This preferentially generate theta at large angles; therefore dec at small angles, near the equator.
                    # (if you randomly uniformly generate dec, you end up with all your points at the pole,
                    # and the CF looks wacky).
                    dec_rand = ( np.pi/2. - np.arccos(np.random.uniform( 0., 1., ngal_cur[plane])) ) * 180./np.pi
                    #
                    shear1_pix_front = hp.get_interp_val( hpmap_g1_front, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                    shear2_pix_front = hp.get_interp_val( hpmap_g2_front, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                    #kappa_pix_front = hp.get_interp_val( hpmap_kappa_front, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )

                    shear1_pix_back  = hp.get_interp_val( hpmap_g1_back,  (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                    shear2_pix_back  = hp.get_interp_val( hpmap_g2_back,  (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                    #kappa_pix_back = hp.get_interp_val( hpmap_kappa_back, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )


                     #
                    # Save a shear catalogue in standard format to be read by Athena
                    #outname = '../../../HACC-Y1/GalCat/StageIV_nz/HACC'+str(IC)+'/V0/seed'+str(seed)+'/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z.asc'
                    #outname = '../../../HACC-Y1/GalCat/SRD-Y1/HACC'+str(IC)+'/noIA/seed'+str(seed)+'/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z.asc'
                    #outname = '../../../HACC-Y1/GalCat/SRD-Y1/HACC'+str(IC)+'/noIA/seed'+str(seed)+'/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_JHDborn.asc'
                    #outname = '../../../HACC-Y1/GalCat/SRD-Y1/HACC'+str(IC)+'/noIA/seed'+str(seed)+'/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_clmax100.asc'
                    #outname = '../../../HACC-Y1/GalCat/SRD-Y1/HACC'+str(IC)+'/noIA/seed'+str(seed)+'/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_nosubsample.asc'
                    #outname = '../../../HACC-Y1/GalCat/SRD-Y1/HACC'+str(IC)+'/noIA/seed'+str(seed)+'/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_auto.asc'
                    #outname = '../../../HACC-Y1/GalCat/SRD-Y1/HACC'+str(IC)+'/noIA/seed'+str(seed)+'/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_nosubsample_nside8192.asc'
                    #outname = '../../../HACC-Y1/GalCat/SRD-Y1/HACC'+str(IC)+'/noIA/seed'+str(seed)+'/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_subsampledensitymax_nside8192.asc'
                    #outname = input.GalDir+'StageIV_nz/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_kappa.asc'
                    outname = '../../../BCM/'+BCM_model+'/GalCat/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z.asc'

                    print("Wrinting",outname)

                    # given ra=np.degrees(phi), e2 DOES NOT NEED FLIPPING.
                    #np.savetxt(outname, np.c_[ra_rand, dec_rand, shear1_pix_front*dz1 + shear1_pix_back*dz2, shear2_pix_front*dz1 + shear2_pix_back*dz2, np.ones(ngal_cur[plane]),spec_z[gal_cur],kappa_pix_front*dz1 + kappa_pix_back*dz2 ])
                    np.savetxt(outname, np.c_[ra_rand, dec_rand, shear1_pix_front*dz1 + shear1_pix_back*dz2, shear2_pix_front*dz1 + shear2_pix_back*dz2, np.ones(ngal_cur[plane]),spec_z[gal_cur] ])

                    #-------------
                elif(OPTION==3):
                    #---------
                    # OPTION 3:
                    # Assign galaxies at positions that trace the underlying dark matter map:
                    # Based on s script from Pierre Burger, PhD Candidate, Bonn University, (2022)

                    #path_in = 'IA-infusion/SkySim5000/density/'
                    #fname = path_in+"density_map_"+str(snaplist[plane])+"_dens_allsky.npy"
                    #print("opening ", fname) 
                    #hpmap_density = np.load(fname)
                    #print("Got density file!")
                    #hp.mollview(hpmap_density[unmask], nest=False)
                    #plt.show()      
                    #must apply Octant mask

                    print("loading delta map:")

                    
                    #HACC:
                    #a = healsparse.HealSparseMap.read(os.path.join(path, f'shells_z{nshells}_subsampledensitymax1.5_nside8192/shell_hacc_seed{seed}_nside8192_imap{ishell}.fits'))
                    #tmp = a.generate_healpix_map()
    
                    ## turn masked pixels to zero.
                    #tmp[tmp<-1.0e+30]=0
                    
                    ## Format is nested, order into ring in order to use alm2maps transforms
                    ## and degrade NSIDE 

                    ## Or reorder, keeping all full NSIDE resolution
                    #hpmap_density = hp.reorder(tmp, n2r = True)
                    #del tmp

                    #BCM:
                    lens_str = str(plane).zfill(2)
                    #filename = '/pscratch/sd/a/avijit97/BCM/HACC/params_dependencies/full_lightcone/Mc/1e14/nshells_51/nshells_'+str(nshells)+'_imap_{}/baryonified_shells_v11.h5'.format(lens_str)
                    filename = '/pscratch/sd/a/avijit97/BCM/HACC/params_dependencies/full_lightcone/Mc/2e14/nshells_51/nshells_'+str(nshells)+'_imap_{}/baryonified_shells_v11.h5'.format(lens_str)
                    #/pscratch/sd/a/avijit97/BCM/HACC/params_dependencies/full_lightcone/Mc/2e14/nshells_51/

                    
                    with h5py.File(filename,'r') as f:
                        #print('h5py file fields:',f.keys())
                        nobaryon_shells = np.array(f['nobaryon_shells'])
                        diff_shells = np.array(f['diff_shells'])
                        #baryon_shells = nobaryon_shells+diff_shells
    
                    if(dmo):
                        hpmap_density=nobaryon_shells
                    else:
                        hpmap_density=nobaryon_shells+diff_shells 


                    print("Got RING-ordered input map")
                    # Normalize the maps correctly:       
                    mean_map = (np.mean(hpmap_density)*8.0) # no factor of 8.0 if we have full sky data here
                    hpmap_density /= mean_map 
                    hpmap_density -= 1
                    print("Transformed from number count to over-density map")

                    lonra = [0, 8]
                    latra = [0, 4]
                    hp.cartview(hpmap_density[0], lonra=lonra, latra=latra,
                                nest=False,
                                title=" matter overdensity",
                                norm=None, unit=None)
                    #hp.projscatter(GalCat[:,0],GalCat[:,1],lonlat=True,marker=(5, 2),c='tab:orange',alpha=0.3)
                    plt.show()
                    #hp.mollview(hpmap_density, nest=False)
                    #plt.show()


                    bias=b_TA
                    pixel_area_arcmin2=pix_size**2          
                    octant_area_arcmin2 = np.sum(hpmap_weight)*pixel_area_arcmin2
                    gpam_z= ngal_cur[plane]/octant_area_arcmin2
                    random.seed(1)

                    n_bar = gpam_z*pixel_area_arcmin2
                    #construct this equation here: n=n_bar*(1+bias*hpmap_density)   
                    hpmap_density*=bias
                    hpmap_density+=1.0
                    hpmap_density*=n_bar
                    print("Transformed from over-density to galaxy density map")

                    negative_n=np.where(hpmap_density<0)[0]
                    hpmap_density[negative_n]=0            
                    print("Enforced positivity everywhere")

                
                    hp.cartview(hpmap_density[0], lonra=lonra, latra=latra,
                                nest=False,
                                title="galaxy overdensity ",
                                norm=None, unit=None)
                    SGD = np.random.poisson(hpmap_density)
                    print("Poisson sampled the map")

                    # Construct the pixel catalogues
                    max_gal = np.max(SGD)
                    print("max Ngal per pixel = ", max_gal)
                    #print(np.where(SGD>0))
                    #pixel=np.where(SGD>0)[0]
                    pixel=np.where(SGD>0)[1]
                    print('got non-zero pixels with size',pixel.shape)
                    #positive_SGD = SGD[pixel]
                    #print(pixel.shape,positive_SGD.shape)
                    print(pixel.shape, pixel)
                    max_gal = np.max(SGD)
                    print("Max number of gal per pixel = ", max_gal)
                    for i in range(1,max_gal):
                        pixel_new=np.where(SGD>i)[1]
                        print("Found ",np.shape(pixel_new), "pixels with more than ",i,"galaxies in it.")
                        print("Adding these to the pixel data vector")
                        pixel = np.hstack([pixel,pixel_new])
                        print(pixel.shape)

                    print('Galaxies live in density with value', SGD[0][pixel[:]])

                    
                    # Poisson sampling means you might endup with slightly more or less galaxies than the true deterministic input
                    # given by ngal_cur[plane]. 

                    #If too much candidates, randomly downsample pixels:
                    if(len(pixel)>=ngal_cur[plane]):
                        pixel=pixel[np.random.choice(len(pixel), size=ngal_cur[plane], replace=False)]
                    else:    
                    #If not enough candidates, randomly downsample the redshifts 
                        gal_tmp = gal_cur[0]
                        down_sampl_pix = np.random.choice(len(gal_tmp), size=len(pixel), replace=False)
                        gal_tmp = gal_tmp[down_sampl_pix]
                        dz1 = dz1[down_sampl_pix]
                        dz2 = dz2[down_sampl_pix]

                        gal_cur = gal_tmp


                    dec_rand,ra_rand = IndexToDeclRa(pixel)
                    print(pixel[0:10], ra_rand[0:10],dec_rand[0:10])
                    # optional: randomly shift the position within the pixels
                    # for this, use the healpy.boundaries() function, with step=1, which
                    # returns the 4 corners of the pixel boundaries. These can be used to 
                    # sample the pixel area.
                    
                    shear1_pix_front = hp.get_interp_val( hpmap_g1_front, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                    shear2_pix_front = hp.get_interp_val( hpmap_g2_front, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                    #kappa_pix_front = hp.get_interp_val( hpmap_kappa_front, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )

                    shear1_pix_back  = hp.get_interp_val( hpmap_g1_back,  (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                    shear2_pix_back  = hp.get_interp_val( hpmap_g2_back,  (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                    #kappa_pix_back = hp.get_interp_val( hpmap_kappa_back, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )


                     #
                    # Save a shear catalogue in standard format to be read by Athena/Treecorr
                    #outname = '../../../HACC-Y1/GalCat/SRD-Y1/HACC'+str(IC)+'/noIA/seed'+str(seed)+'/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_subsampledensitymax_nside8192_linear_bias.asc'
                    #outname = '../../../HACC-Y1/GalCat/SRD-Y1/HACC'+str(IC)+'/noIA/seed'+str(seed)+'/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_subsampledensitymax_nside8192_linear_bias_bta2.asc'
                    outname = '../../../BCM/'+BCM_model+'/GalCat/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_linear_bias.asc'
 
                    print("Wrinting",outname)
                    np.savetxt(outname, np.c_[ra_rand, dec_rand, shear1_pix_front*dz1 + shear1_pix_back*dz2, shear2_pix_front*dz1 + shear2_pix_back*dz2, np.ones(len(pixel)),spec_z[gal_cur] ])
                    print("Done")

                    hp.projscatter(ra_rand, dec_rand,lonlat=True,marker='.',c='tab:orange',alpha=0.3)
                    plt.show()

                    del SGD 
                    del hpmap_density




        print("***************************")
        print("Done writing all catalogues")
        print("***************************")

# %%
def PopulateSkySim5000(spec_z,tomobin,gpam):

    import random


    #find galaxies with shear planes i and j, load the maps, interpolate, loop over next maps
    #z_list = np.loadtxt('list_zs.dat')

    # Selection population option:
    # 1 = randomly choose pixels from the unmasked section of the map, only good for flat sky.
    # 2 = randomly generate angular coords from the unmasked octant (more accurate than OPTION 1)
    # 3 = load mass sheet and populate the galaxies following a linear biasing scheme
    OPTION=3
    b_TA=2.0

    zfile=np.loadtxt("z2ts.txt",delimiter=',')
    snaplist = np.flip(zfile[1:58,1]).astype(int)
    z_list=np.flip(zfile[1:58,0])

    n_slices = np.size(z_list)
    #print(zfile)
    #print(z_list)

    ngal_cur = np.zeros(n_slices, dtype=int)

    ngal_analyzed = 0
    weight_flag = 0
    recycle_map_flag = 0

    # Loop over all planes, starting from high redshift towards z=0
    #for plane in range(36,37):
    for plane in range(0,n_slices):

        print('starting analysis of plane %i' % plane)

        #--------------------------------------
        # Get redshifts of the source planes:
        z_back = z_list[plane]
        if plane == n_slices-1:
            z_front = 0.0
        else:
            z_front = z_list[plane+1]
        print('z_lo - z_hi =', z_front, z_back)
        #--------------------------------------



        gal_cur = np.where(np.logical_and(spec_z>z_front, spec_z<=z_back))
        ngal_cur[plane] = np.size(gal_cur)
        if ngal_cur[plane] == 0:
            print('no galaxies here, loop to next plane')
        else:
            print('found %s galaxies between z=%f and z=%f' % (ngal_cur[plane], z_front, z_back))
            ngal_analyzed = ngal_analyzed+ngal_cur[plane]
            #
            if ngal_cur[plane-1] >0:
                print("Found consecutive planes not empty, recycle planes to save IO:")
                recycle_map_flag = 1
                # Uncomment the above to enable recycling

            #Interpolate from shear maps onto redshift of the halo:
            #! dz1 (dz2) is fractional distance to plane behind (in front)
            #
            dz1 = z_back - spec_z[gal_cur]
            if plane == n_slices -1:
                dz2 = spec_z[gal_cur]
            else: 
                dz2 = spec_z[gal_cur] - z_front
            #
            dz1 = dz1/(dz1 + dz2)
            dz2 = 1. - dz1
            #
            #print(z_front, spec_z[gal_cur], z_back, dz1, dz2)

            if weight_flag == 0:
                print('reading weight file')
                weight_flag = 1
                print("Reading in weight map for OuterRim/Mira Titan")
                hpmap_weight = hp.fitsfunc.read_map('../../FullSky_weight.fits', field=0,nest=False, partial=False, hdu=1, h=False, verbose=True, memmap=True)
                #
                # masking - not really necessary here, but just in case it is useful for something else.
                unmask = np.where(hpmap_weight > 0)[0]
                #
            if recycle_map_flag==0:
                print("Reading in shear 1 back (zs = %f)" % z_back)
                print("Reading in shear 2 back (zs = %f)" % z_back)

                fname1 = "../../shear/"+str("{:5.4f}".format(z_back))+"gamma1.npy"
                fname2 = "../../shear/"+str("{:5.4f}".format(z_back))+"gamma2.npy"
                #fname3 = input.kappaDir+str("{:5.4f}".format(z_back))+"kappa.npy"

                hpmap_g1_back = np.load(fname1)
                print("loaded gamma1")

                hpmap_g2_back = np.load(fname2)
                print("loaded gamma2")                                    

                #hpmap_kappa_back = np.load(fname3)
                #print("loaded kappa")                                    


            else:
                print("Recycling map to reduce IO:, zs = %f was already loaded, now used as back plane" % z_back)
                hpmap_g1_back= hpmap_g1_front
                hpmap_g2_back= hpmap_g2_front
                #hpmap_kappa_back= hpmap_kappa_front

                recycle_map_flag = 0
            #
            print("Reading in shear 1/2/kappa front (zs = %f)" % z_front)

            if z_front==0:
                hpmap_g1_front = hpmap_g1_back - hpmap_g1_back
                hpmap_g2_front = hpmap_g2_back - hpmap_g2_back
                #hpmap_kappa_front = hpmap_kappa_back - hpmap_kappa_back

            else:
                fname1 = "../../shear/"+str("{:5.4f}".format(z_front))+"gamma1.npy"
                fname2 = "../../shear/"+str("{:5.4f}".format(z_front))+"gamma2.npy"
                #fname3 = input.kappaDir+str("{:5.4f}".format(z_front))+"kappa.npy"


                hpmap_g1_front = np.load(fname1)
                print("loaded gamma1")

                hpmap_g2_front = np.load(fname2)
                print("loaded gamma2")                                    

                #hpmap_kappa_front = np.load(fname3)
                #print("loaded kappa")                                    


            # Got shear and kappa maps 


            #-------------
            if(OPTION==1):
                # OPTION 1:
                # randomly choose pixels from the unmasked section of the map
                # Only good for flat sky.
                print('Getting the indicies for %s random unmasked galaxies' %ngal_cur[plane])
                idx = np.random.choice(unmask, int(ngal_cur[plane]))
                #print idx
                #
                # get the ra and dec of these pixels
                dec,ra= IndexToDeclRa( idx )
                #
                # get the shear maps at these pixels
                shear1_pix_front = hpmap_g1_front[idx]
                shear2_pix_front = hpmap_g2_front[idx]
                shear1_pix_back = hpmap_g1_back[idx]
                shear2_pix_back = hpmap_g2_back[idx]
                #
                np.savetxt('./MyProject/MT_nz_LSST_lmax5000%sGpAM_zfront%s_z_back%s.asc'%(gpam,z_front, z_back), np.c_[ra, dec, shear1_pix_front*dz1 + shear1_pix_back*dz2, shear2_pix_front*dz1 + shear2_pix_back*dz2,spec_z[gal_cur]])

                #-------------
            elif(OPTION==2):
                # OPTION 2:
                # randomly generate angular coords from the unmasked octant, and use healpy interpolation
                # function to get the shear at these locations
                dec,ra = IndexToDeclRa( unmask )
                ra_rand = np.random.uniform( np.min(ra), np.max(ra), ngal_cur[plane])
                #
                # This preferentially generate theta at large angles; therefore dec at small angles, near the equator.
                # (if you randomly uniformly generate dec, you end up with all your points at the pole,
                # and the CF looks wacky).
                dec_rand = ( np.pi/2. - np.arccos(np.random.uniform( 0., 1., ngal_cur[plane])) ) * 180./np.pi
                #
                shear1_pix_front = hp.get_interp_val( hpmap_g1_front, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                shear2_pix_front = hp.get_interp_val( hpmap_g2_front, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                #kappa_pix_front = hp.get_interp_val( hpmap_kappa_front, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )

                shear1_pix_back  = hp.get_interp_val( hpmap_g1_back,  (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                shear2_pix_back  = hp.get_interp_val( hpmap_g2_back,  (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                #kappa_pix_back = hp.get_interp_val( hpmap_kappa_back, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )


                 #
                # Save a shear catalogue in standard format to be read by Athena
                #outname = "../../GalCat/"+'StageIV_nz/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w.asc'
                outname = '../../GalCat/SRD-Y1/random_pos/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z.asc'
                #outname = input.GalDir+'StageIV_nz/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_kappa.asc'

                print("Wrinting",outname)

                # given ra=np.degrees(phi), e2 DOES NOT NEED FLIPPING.
                #np.savetxt(outname, np.c_[ra_rand, dec_rand, shear1_pix_front*dz1 + shear1_pix_back*dz2, shear2_pix_front*dz1 + shear2_pix_back*dz2, np.ones(ngal_cur[plane]),spec_z[gal_cur],kappa_pix_front*dz1 + kappa_pix_back*dz2 ])
                np.savetxt(outname, np.c_[ra_rand, dec_rand, shear1_pix_front*dz1 + shear1_pix_back*dz2, shear2_pix_front*dz1 + shear2_pix_back*dz2, np.ones(ngal_cur[plane]),spec_z[gal_cur] ])

                #-------------
            elif(OPTION==3):
                #---------
                # OPTION 3:
                # Assign galaxies at positions that trace the underlying dark matter map:
                # Based on a script from Pierre Burger, PhD Candidate, Bonn University, (2022)
    
                smoothing = '1' #'None', 1, '05' or '01'
    
                if (smoothing=='None'): 
                    path_in="/global/cfs/cdirs/lsst/groups/CS/mass_sheets/"
                    print("loading delta map:")
                    fname = path_in+'density_map_'+str(snaplist[plane])+'_dens.bin'
                    print('Working on file '+fname)
                    tmp = np.fromfile(fname,'<f')

                    # Format is nested, reorder pixels into ring in order to use alm2maps transforms
                    # and potentially degrade NSIDE 
                    #print("NSIDE_orig=", hp.get_nside(tmp))
                    #binmap=hp.pixelfunc.ud_grade(tmp, 4096, pess=False, order_in='NESTED', order_out='RING', power=None, dtype=None)
                    #print("NSIDE_new=", hp.get_nside(binmap))

                    # Or reorder, keeping all full NSIDE resolution
                    hpmap_density = hp.reorder(tmp, n2r = True)
                    del tmp

                else:
                    fname='../../density/density_'+str(snaplist[plane])+'_smooth_'+smoothing+'arcmin.npy'
                    hpmap_density = np.load(fname)
                    
                print("Got RING-ordered input map")
                # Normalize the maps correctly:       
                mean_map = (np.mean(hpmap_density)*8.0) # factor of 8.0 since we have octant
                hpmap_density /= mean_map 
                hpmap_density -= 1
                hpmap_density*=hpmap_weight # Applied mask
                print("Transformed from number count to over-density map, with mask")

               
                bias=b_TA
                pixel_area_arcmin2=pix_size**2          
                octant_area_arcmin2 = np.sum(hpmap_weight)*pixel_area_arcmin2
                gpam_z_per_arcmin2= ngal_cur[plane]/octant_area_arcmin2
                random.seed(1)

                n_bar = gpam_z_per_arcmin2*pixel_area_arcmin2 # mean number of galaxies per pixel
                #------------------------
                #construct this equation: n(x)=n_bar*(1+bias*delta(x))   
                #------------------------
                
                hpmap_density*=bias
                hpmap_density+=1.0
                hpmap_density*=n_bar
                hpmap_density*=hpmap_weight # Applied mask

                print("Transformed from over-density to galaxy density map")

                negative_n=np.where(hpmap_density<0)[0]
                hpmap_density[negative_n]=0            
                print("Enforced positivity everywhere")

                SGD = np.random.poisson(hpmap_density)
                print("Poisson sampled the map")

                # Construct the catalogues
                max_gal = np.max(SGD)
                print("max Ngal per pixel = ", max_gal)
                pixel=np.where(SGD>0)[0]
                print("Got non-empty pixels")
                positive_SGD = SGD[pixel]
                print(pixel.shape,positive_SGD.shape)
                max_gal = np.max(SGD)
                print("Max number of gal per pixel = ", max_gal)
                for i in range(1,max_gal):
                    pixel_new=np.where(SGD>i)[0]
                    print("Found ",np.shape(pixel_new), "pixels with more than ",i,"galaxies in it.")
                    print("Adding these to the pixel data vector")
                    pixel = np.hstack([pixel,pixel_new])
                    print(pixel.shape)

                
                # Poisson sampling means you might endup with slightly more or less galaxies than the true deterministic input
                # given by ngal_cur[plane]. 

                #If too much candidates, randomly downsample pixels:
                if(len(pixel)>=ngal_cur[plane]):
                    pixel=pixel[np.random.choice(len(pixel), size=ngal_cur[plane], replace=False)]
                else:    
                #If not enough candidates, randomly downsample the redshifts 
                    gal_tmp = gal_cur[0]
                    down_sampl_pix = np.random.choice(len(gal_tmp), size=len(pixel), replace=False)
                    gal_tmp = gal_tmp[down_sampl_pix]
                    dz1 = dz1[down_sampl_pix]
                    dz2 = dz2[down_sampl_pix]

                    gal_cur = gal_tmp
                    
                dec_rand,ra_rand = IndexToDeclRa(pixel)

                
                #----------
                #hp.mollview(hpmap_density, nest=False)
                #plt.show()
                #----------
                lonra = [0, 2]
                latra = [0, 1]
                hp.cartview(hpmap_density,
                    cbar=True, lonra=lonra, latra=latra,
                    nest=False,
                    title=" ",
                    # min=-10, max=0,
                    cmap=plt.cm.coolwarm,
                    norm=None, unit='delta')
                #plt.show()
                                
                hp.projscatter(ra_rand,dec_rand,lonlat=True,marker=(5, 2),c='tab:orange',alpha=0.5)
                plt.show()
 
                
                # optional: randomly shift the position within the pixels
                # for this, use the healpy.boundaries() function, with step=1, which
                # returns the 4 corners of the pixel boundaries. These can be used to 
                # sample the pixel area.

                shear1_pix_front = hp.get_interp_val( hpmap_g1_front, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                shear2_pix_front = hp.get_interp_val( hpmap_g2_front, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                #kappa_pix_front = hp.get_interp_val( hpmap_kappa_front, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )

                shear1_pix_back  = hp.get_interp_val( hpmap_g1_back,  (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                shear2_pix_back  = hp.get_interp_val( hpmap_g2_back,  (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                #kappa_pix_back = hp.get_interp_val( hpmap_kappa_back, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )


                 #
                # Save a shear catalogue in standard format to be read by Athena/Treecorr
                if (smoothing=='None'): 
                    #outname = '../../GalCat/StageIV_nz/V1/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_linear_bias.asc'
                    #outname = '../../GalCat/StageIV_nz/V1/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_linear_bias_bta2.asc'
                    #outname = '../../GalCat/SRD-Y1/V1/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_linear_bias_bta2.asc'
                    #outname = '../../GalCat/SRD-Y1/lin_bias_pos/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_linear_bias_bta1.asc'
                    outname = '../../GalCat/SRD-Y1/lin_bias_pos/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_linear_bias_bta2.asc'
                else:
                    #outname = '../../GalCat/SRD-Y1/lin_bias_pos/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_linear_bias_smooth'+smoothing+'_bta1.asc'
                    outname = '../../GalCat/SRD-Y1/lin_bias_pos/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_linear_bias_smooth'+smoothing+'_bta2.asc'
                   
                print("Wrinting",outname)
                np.savetxt(outname, np.c_[ra_rand, dec_rand, shear1_pix_front*dz1 + shear1_pix_back*dz2, shear2_pix_front*dz1 + shear2_pix_back*dz2, np.ones(len(pixel)),spec_z[gal_cur] ])
                print("Done")

                del SGD 
                del hpmap_density




    print("***************************")
    print("Done writing all catalogues")
    print("***************************")

# %%
def PopulateFS(spec_z,tomobin,gpam):

    import random


    #find galaxies with shear planes i and j, load the maps, interpolate, loop over next maps
    #z_list = np.loadtxt('list_zs.dat')

    # Selection population option:
    # 1 = randomly choose pixels from the unmasked section of the map, only good for flat sky.
    # 2 = randomly generate angular coords from the unmasked octant (more accurate than OPTION 1)
    # 3 = load mass sheet and populate the galaxies following a linear biasing scheme
    OPTION=2
    b_TA=1.0

    #zfile=np.loadtxt("z2ts.txt",delimiter=',')
    #snaplist = np.flip(zfile[1:58,1]).astype(int)
    #z_list=np.flip(zfile[1:58,0])
    
    zfile = np.loadtxt("/global/cfs/cdirs/m5099/FS2/steps.fs2.ssv",skiprows=1)
    #This is structured as:
    # step dist_min dist_max dist_median z_median a_median, distances in Mpc/h
    #comoving_edges = np.hstack([np.array(zfile[:,1]),np.array(zfile[:,2])[-1]])/cosmo.h # 

    #zfile should contain redshifts of lens planes, starting from low-redshift
    #zfile=np.loadtxt("z2ts_HACCY1_51.txt",delimiter=' ')
    snaplist = np.flip(zfile[0:128,0].astype(int))

    chi_upper_Mpc = zfile[0:128,2]/ ncosmo.h
    z_list = np.flip(z_at_value(ncosmo.comoving_distance,chi_upper_Mpc*u.Mpc).value)

    n_slices = np.size(z_list)
    #print(zfile)
    #print(z_list)

    ngal_cur = np.zeros(n_slices, dtype=int)

    ngal_analyzed = 0
    weight_flag = 0
    recycle_map_flag = 0

    # Loop over all planes, starting from high redshift towards z=0
    #for plane in range(36,37):
    for plane in range(0,n_slices):

        print('starting analysis of plane %i' % plane)

        #--------------------------------------
        # Get redshifts of the source planes:
        z_back = z_list[plane]
        if plane == n_slices-1:
            z_front = 0.0
        else:
            z_front = z_list[plane+1]
        print('z_lo - z_hi =', z_front, z_back)
        #--------------------------------------



        gal_cur = np.where(np.logical_and(spec_z>z_front, spec_z<=z_back))
        ngal_cur[plane] = np.size(gal_cur)
        if ngal_cur[plane] == 0:
            print('no galaxies here, loop to next plane')
        else:
            print('found %s galaxies between z=%f and z=%f' % (ngal_cur[plane], z_front, z_back))
            ngal_analyzed = ngal_analyzed+ngal_cur[plane]
            #
            if ngal_cur[plane-1] >0:
                print("Found consecutive planes not empty, recycle planes to save IO:")
                recycle_map_flag = 1
                # Uncomment the above to enable recycling

            #Interpolate from shear maps onto redshift of the halo:
            #! dz1 (dz2) is fractional distance to plane behind (in front)
            #
            dz1 = z_back - spec_z[gal_cur]
            if plane == n_slices -1:
                dz2 = spec_z[gal_cur]
            else: 
                dz2 = spec_z[gal_cur] - z_front
            #
            dz1 = dz1/(dz1 + dz2)
            dz2 = 1. - dz1
            #
            #print(z_front, spec_z[gal_cur], z_back, dz1, dz2)

            
            #if weight_flag == 0:
            #    print('reading weight file')
            #    weight_flag = 1
            #    print("Reading in weight map for OuterRim/Mira Titan")
            #    hpmap_weight = hp.fitsfunc.read_map('../../FullSky_weight.fits', field=0,nest=False, partial=False, hdu=1, h=False, verbose=True, memmap=True)
                #
                # masking - not really necessary here, but just in case it is useful for something else.
                #unmask = np.where(hpmap_weight > 0)[0]
                #
            if recycle_map_flag==0:
                print("Reading in shear 1 back (zs = %f)" % z_back)
                print("Reading in shear 2 back (zs = %f)" % z_back)

                fname1 = path_out+"/shear/"+str("{:5.4f}".format(z_back))+"gamma1.npy"
                fname2 = path_out+"/shear/"+str("{:5.4f}".format(z_back))+"gamma2.npy"
                #fname3 = input.kappaDir+str("{:5.4f}".format(z_back))+"kappa.npy"

                hpmap_g1_back = np.load(fname1)
                print("loaded gamma1")

                hpmap_g2_back = np.load(fname2)
                print("loaded gamma2")                                    

                #hpmap_kappa_back = np.load(fname3)
                #print("loaded kappa")                                    

            else:
                print("Recycling map to reduce IO:, zs = %f was already loaded, now used as back plane" % z_back)
                hpmap_g1_back= hpmap_g1_front
                hpmap_g2_back= hpmap_g2_front
                #hpmap_kappa_back= hpmap_kappa_front

                recycle_map_flag = 0
            #
            print("Reading in shear 1/2/kappa front (zs = %f)" % z_front)

            if z_front==0:
                hpmap_g1_front = hpmap_g1_back - hpmap_g1_back
                hpmap_g2_front = hpmap_g2_back - hpmap_g2_back
                #hpmap_kappa_front = hpmap_kappa_back - hpmap_kappa_back

            else:
                fname1 = path_out+"/shear/"+str("{:5.4f}".format(z_front))+"gamma1.npy"
                fname2 = path_out+"/shear/"+str("{:5.4f}".format(z_front))+"gamma2.npy"
                #fname3 = input.kappaDir+str("{:5.4f}".format(z_front))+"kappa.npy"


                hpmap_g1_front = np.load(fname1)
                print("loaded gamma1")

                hpmap_g2_front = np.load(fname2)
                print("loaded gamma2")                                    

                #hpmap_kappa_front = np.load(fname3)
                #print("loaded kappa")                                    


            # Got shear and kappa maps 

            unmask = np.where(hpmap_g1_back > -99)[0]


            #-------------
            if(OPTION==1):
                # OPTION 1:
                # randomly choose pixels from the unmasked section of the map
                # Only good for flat sky.
                print('Getting the indicies for %s random unmasked galaxies' %ngal_cur[plane])
                idx = np.random.choice(unmask, int(ngal_cur[plane]))
                #print idx
                #
                # get the ra and dec of these pixels
                dec,ra= IndexToDeclRa( idx )
                #
                # get the shear maps at these pixels
                shear1_pix_front = hpmap_g1_front[idx]
                shear2_pix_front = hpmap_g2_front[idx]
                shear1_pix_back = hpmap_g1_back[idx]
                shear2_pix_back = hpmap_g2_back[idx]
                #
                np.savetxt('./MyProject/MT_nz_LSST_lmax5000%sGpAM_zfront%s_z_back%s.asc'%(gpam,z_front, z_back), np.c_[ra, dec, shear1_pix_front*dz1 + shear1_pix_back*dz2, shear2_pix_front*dz1 + shear2_pix_back*dz2,spec_z[gal_cur]])

                #-------------
            elif(OPTION==2):
                # OPTION 2:
                # randomly generate angular coords from the unmasked octant, and use healpy interpolation
                # function to get the shear at these locations
                dec,ra = IndexToDeclRa( unmask )
                ra_rand = np.random.uniform( np.min(ra), np.max(ra), ngal_cur[plane])
                #
                # This preferentially generate theta at large angles; therefore dec at small angles, near the equator.
                # (if you randomly uniformly generate dec, you end up with all your points at the pole,
                # and the CF looks wacky).
                dec_rand = ( np.pi/2. - np.arccos(np.random.uniform( 0., 1., ngal_cur[plane])) ) * 180./np.pi
                #
                shear1_pix_front = hp.get_interp_val( hpmap_g1_front, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                shear2_pix_front = hp.get_interp_val( hpmap_g2_front, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                #kappa_pix_front = hp.get_interp_val( hpmap_kappa_front, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )

                shear1_pix_back  = hp.get_interp_val( hpmap_g1_back,  (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                shear2_pix_back  = hp.get_interp_val( hpmap_g2_back,  (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                #kappa_pix_back = hp.get_interp_val( hpmap_kappa_back, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )


                 #
                # Save a shear catalogue in standard format to be read by Athena
                #outname = "../../GalCat/"+'StageIV_nz/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w.asc'
                outname = path_out+'/GalCat/RR2_V2/random_pos/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z.asc'
                #outname = input.GalDir+'StageIV_nz/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_kappa.asc'

                print("Wrinting",outname)

                # given ra=np.degrees(phi), e2 DOES NOT NEED FLIPPING.
                #np.savetxt(outname, np.c_[ra_rand, dec_rand, shear1_pix_front*dz1 + shear1_pix_back*dz2, shear2_pix_front*dz1 + shear2_pix_back*dz2, np.ones(ngal_cur[plane]),spec_z[gal_cur],kappa_pix_front*dz1 + kappa_pix_back*dz2 ])
                np.savetxt(outname, np.c_[ra_rand, dec_rand, shear1_pix_front*dz1 + shear1_pix_back*dz2, shear2_pix_front*dz1 + shear2_pix_back*dz2, np.ones(ngal_cur[plane]),spec_z[gal_cur] ])

                #-------------
            elif(OPTION==3):
                #---------
                # OPTION 3:
                # Assign galaxies at positions that trace the underlying dark matter map:
                # Based on a script from Pierre Burger, PhD Candidate, Bonn University, (2022)
    
                smoothing = '1' #'None', 1, '05' or '01'
    
                if (smoothing=='None'): 
                    path_in="/global/cfs/cdirs/lsst/groups/CS/mass_sheets/"
                    print("loading delta map:")
                    fname = path_in+'density_map_'+str(snaplist[plane])+'_dens.bin'
                    print('Working on file '+fname)
                    tmp = np.fromfile(fname,'<f')

                    # Format is nested, reorder pixels into ring in order to use alm2maps transforms
                    # and potentially degrade NSIDE 
                    #print("NSIDE_orig=", hp.get_nside(tmp))
                    #binmap=hp.pixelfunc.ud_grade(tmp, 4096, pess=False, order_in='NESTED', order_out='RING', power=None, dtype=None)
                    #print("NSIDE_new=", hp.get_nside(binmap))

                    # Or reorder, keeping all full NSIDE resolution
                    hpmap_density = hp.reorder(tmp, n2r = True)
                    del tmp

                else:
                    fname='../../density/density_'+str(snaplist[plane])+'_smooth_'+smoothing+'arcmin.npy'
                    hpmap_density = np.load(fname)
                    
                print("Got RING-ordered input map")
                # Normalize the maps correctly:       
                mean_map = (np.mean(hpmap_density)*8.0) # factor of 8.0 since we have octant
                hpmap_density /= mean_map 
                hpmap_density -= 1
                hpmap_density*=hpmap_weight # Applied mask
                print("Transformed from number count to over-density map, with mask")

               
                bias=b_TA
                pixel_area_arcmin2=pix_size**2          
                octant_area_arcmin2 = np.sum(hpmap_weight)*pixel_area_arcmin2
                gpam_z_per_arcmin2= ngal_cur[plane]/octant_area_arcmin2
                random.seed(1)

                n_bar = gpam_z_per_arcmin2*pixel_area_arcmin2 # mean number of galaxies per pixel
                #------------------------
                #construct this equation: n(x)=n_bar*(1+bias*delta(x))   
                #------------------------
                
                hpmap_density*=bias
                hpmap_density+=1.0
                hpmap_density*=n_bar
                hpmap_density*=hpmap_weight # Applied mask

                print("Transformed from over-density to galaxy density map")

                negative_n=np.where(hpmap_density<0)[0]
                hpmap_density[negative_n]=0            
                print("Enforced positivity everywhere")

                SGD = np.random.poisson(hpmap_density)
                print("Poisson sampled the map")

                # Construct the catalogues
                max_gal = np.max(SGD)
                print("max Ngal per pixel = ", max_gal)
                pixel=np.where(SGD>0)[0]
                print("Got non-empty pixels")
                positive_SGD = SGD[pixel]
                print(pixel.shape,positive_SGD.shape)
                max_gal = np.max(SGD)
                print("Max number of gal per pixel = ", max_gal)
                for i in range(1,max_gal):
                    pixel_new=np.where(SGD>i)[0]
                    print("Found ",np.shape(pixel_new), "pixels with more than ",i,"galaxies in it.")
                    print("Adding these to the pixel data vector")
                    pixel = np.hstack([pixel,pixel_new])
                    print(pixel.shape)

                
                # Poisson sampling means you might endup with slightly more or less galaxies than the true deterministic input
                # given by ngal_cur[plane]. 

                #If too much candidates, randomly downsample pixels:
                if(len(pixel)>=ngal_cur[plane]):
                    pixel=pixel[np.random.choice(len(pixel), size=ngal_cur[plane], replace=False)]
                else:    
                #If not enough candidates, randomly downsample the redshifts 
                    gal_tmp = gal_cur[0]
                    down_sampl_pix = np.random.choice(len(gal_tmp), size=len(pixel), replace=False)
                    gal_tmp = gal_tmp[down_sampl_pix]
                    dz1 = dz1[down_sampl_pix]
                    dz2 = dz2[down_sampl_pix]

                    gal_cur = gal_tmp
                    
                dec_rand,ra_rand = IndexToDeclRa(pixel)

                
                #----------
                #hp.mollview(hpmap_density, nest=False)
                #plt.show()
                #----------
                lonra = [0, 2]
                latra = [0, 1]
                hp.cartview(hpmap_density,
                    cbar=True, lonra=lonra, latra=latra,
                    nest=False,
                    title=" ",
                    # min=-10, max=0,
                    cmap=plt.cm.coolwarm,
                    norm=None, unit='delta')
                #plt.show()
                                
                hp.projscatter(ra_rand,dec_rand,lonlat=True,marker=(5, 2),c='tab:orange',alpha=0.5)
                plt.show()
 
                
                # optional: randomly shift the position within the pixels
                # for this, use the healpy.boundaries() function, with step=1, which
                # returns the 4 corners of the pixel boundaries. These can be used to 
                # sample the pixel area.

                shear1_pix_front = hp.get_interp_val( hpmap_g1_front, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                shear2_pix_front = hp.get_interp_val( hpmap_g2_front, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                #kappa_pix_front = hp.get_interp_val( hpmap_kappa_front, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )

                shear1_pix_back  = hp.get_interp_val( hpmap_g1_back,  (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                shear2_pix_back  = hp.get_interp_val( hpmap_g2_back,  (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )
                #kappa_pix_back = hp.get_interp_val( hpmap_kappa_back, (90.-dec_rand)*np.pi/180., ra_rand*np.pi/180., nest=False )


                 #
                # Save a shear catalogue in standard format to be read by Athena/Treecorr
                if (smoothing=='None'): 
                    #outname = '../../GalCat/StageIV_nz/V1/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_linear_bias.asc'
                    #outname = '../../GalCat/StageIV_nz/V1/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_linear_bias_bta2.asc'
                    #outname = '../../GalCat/SRD-Y1/V1/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_linear_bias_bta2.asc'
                    #outname = '../../GalCat/SRD-Y1/lin_bias_pos/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_linear_bias_bta1.asc'
                    outname = '../../GalCat/SRD-Y1/lin_bias_pos/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_linear_bias_bta2.asc'
                else:
                    #outname = '../../GalCat/SRD-Y1/lin_bias_pos/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_linear_bias_smooth'+smoothing+'_bta1.asc'
                    outname = '../../GalCat/SRD-Y1/lin_bias_pos/GalCat_tomo'+str(tomobin)+'_plane'+str(plane)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_linear_bias_smooth'+smoothing+'_bta2.asc'
                   
                print("Wrinting",outname)
                np.savetxt(outname, np.c_[ra_rand, dec_rand, shear1_pix_front*dz1 + shear1_pix_back*dz2, shear2_pix_front*dz1 + shear2_pix_back*dz2, np.ones(len(pixel)),spec_z[gal_cur] ])
                print("Done")

                del SGD 
                del hpmap_density




    print("***************************")
    print("Done writing all catalogues")
    print("***************************")

# %%
#run pipeline:
    
# The tomographic bin
for tomobin in range(1,7):
    
    print("**************************")
    print("Processing tomo bin",tomobin)
    print("**************************")
    
    # 1- Read N(z)    
    n_zbins,z_array,pdz,dz = GetNz(nz_filename,tomobin)

    # 2- Assign Redshifts
    spec_z = AssignRedshifts(n_zbins,pdz,dz)

    # 3- Plot input n(z) vs galaxy histogram
    PlotNz(spec_z,z_array,dz,pdz,tomobin)

    # 4- Make catalogue
    if(SkySim):
        PopulateSkySim5000(spec_z,tomobin,gpam)
    elif(HACCY1):
        PopulateHACCY1(spec_z,tomobin,gpam,IC,seed,nshells)
    elif(FS):
        PopulateFS(spec_z,tomobin,gpam)
# Out:
# **************************
# Processing tomo bin 1
# **************************
# Reading in N(z) from tomobin  1
# Check normalisation: sum n(z) dz =  1.0000000000000004
# Mean redshift =  0.41819499831510193
# Got cumul dist
# Assigned redshift to these galaxies
# -----------------------------------
# starting analysis of plane 0
# z_lo - z_hi = 3.7361844886237394 3.9264629876272985
# no galaxies here, loop to next plane
# starting analysis of plane 1
# z_lo - z_hi = 3.5629486328478475 3.7361844886237394
# no galaxies here, loop to next plane
# starting analysis of plane 2
# z_lo - z_hi = 3.4044349035302233 3.5629486328478475
# no galaxies here, loop to next plane
# starting analysis of plane 3
# z_lo - z_hi = 3.2587314425180334 3.4044349035302233
# no galaxies here, loop to next plane
# starting analysis of plane 4
# z_lo - z_hi = 3.124253335513705 3.2587314425180334
# no galaxies here, loop to next plane
# starting analysis of plane 5
# z_lo - z_hi = 2.9996723279698556 3.124253335513705
# found 6282 galaxies between z=2.999672 and z=3.124253
# Reading in shear 1 back (zs = 3.124253)
# Reading in shear 2 back (zs = 3.124253)
# loaded gamma1
# loaded gamma2
# Reading in shear 1/2/kappa front (zs = 2.999672)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane5_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 6
# z_lo - z_hi = 2.88386821865382 2.9996723279698556
# found 23609 galaxies between z=2.883868 and z=2.999672
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 2.999672 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 2.883868)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane6_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 7
# z_lo - z_hi = 2.7758836157807254 2.88386821865382
# found 16391 galaxies between z=2.775884 and z=2.883868
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 2.883868 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 2.775884)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane7_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 8
# z_lo - z_hi = 2.6749042562560446 2.7758836157807254
# found 13103 galaxies between z=2.674904 and z=2.775884
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 2.775884 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 2.674904)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane8_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 9
# z_lo - z_hi = 2.580222890160134 2.6749042562560446
# found 10156 galaxies between z=2.580223 and z=2.674904
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 2.674904 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 2.580223)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane9_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 10
# z_lo - z_hi = 2.491229151300818 2.580222890160134
# found 10203 galaxies between z=2.491229 and z=2.580223
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 2.580223 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 2.491229)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane10_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 11
# z_lo - z_hi = 2.4073915629705436 2.491229151300818
# found 8263 galaxies between z=2.407392 and z=2.491229
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 2.491229 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 2.407392)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane11_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 12
# z_lo - z_hi = 2.3282424935231 2.4073915629705436
# found 4491 galaxies between z=2.328242 and z=2.407392
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 2.407392 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 2.328242)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane12_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 13
# z_lo - z_hi = 2.253371750140508 2.3282424935231
# found 4765 galaxies between z=2.253372 and z=2.328242
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 2.328242 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 2.253372)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane13_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 14
# z_lo - z_hi = 2.182416875215883 2.253371750140508
# found 3936 galaxies between z=2.182417 and z=2.253372
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 2.253372 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 2.182417)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane14_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 15
# z_lo - z_hi = 2.1150557347043897 2.182416875215883
# found 3579 galaxies between z=2.115056 and z=2.182417
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 2.182417 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 2.115056)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane15_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 16
# z_lo - z_hi = 2.0510022159325145 2.1150557347043897
# found 3269 galaxies between z=2.051002 and z=2.115056
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 2.115056 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 2.051002)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane16_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 17
# z_lo - z_hi = 1.9899989173300172 2.0510022159325145
# found 4606 galaxies between z=1.989999 and z=2.051002
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 2.051002 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.989999)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane17_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 18
# z_lo - z_hi = 1.9318168425100977 1.9899989173300172
# found 3345 galaxies between z=1.931817 and z=1.989999
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.989999 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.931817)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane18_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 19
# z_lo - z_hi = 1.8762492840336003 1.9318168425100977
# found 2719 galaxies between z=1.876249 and z=1.931817
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.931817 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.876249)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane19_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 20
# z_lo - z_hi = 1.8231106178411036 1.8762492840336003
# found 1882 galaxies between z=1.823111 and z=1.876249
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.876249 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.823111)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane20_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 21
# z_lo - z_hi = 1.7722310942458583 1.8231106178411036
# found 3037 galaxies between z=1.772231 and z=1.823111
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.823111 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.772231)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane21_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 22
# z_lo - z_hi = 1.7234568126845942 1.7722310942458583
# found 1604 galaxies between z=1.723457 and z=1.772231
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.772231 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.723457)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane22_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 23
# z_lo - z_hi = 1.6766506210488181 1.7234568126845942
# found 2110 galaxies between z=1.676651 and z=1.723457
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.723457 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.676651)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane23_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 24
# z_lo - z_hi = 1.6316849307619377 1.6766506210488181
# found 2217 galaxies between z=1.631685 and z=1.676651
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.676651 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.631685)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane24_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 25
# z_lo - z_hi = 1.5884427306548776 1.6316849307619377
# found 1756 galaxies between z=1.588443 and z=1.631685
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.631685 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.588443)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane25_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 26
# z_lo - z_hi = 1.546818472001233 1.5884427306548776
# found 1942 galaxies between z=1.546818 and z=1.588443
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.588443 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.546818)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane26_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 27
# z_lo - z_hi = 1.5067160650869769 1.546818472001233
# found 2823 galaxies between z=1.506716 and z=1.546818
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.546818 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.506716)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane27_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 28
# z_lo - z_hi = 1.468043782582634 1.5067160650869769
# found 3334 galaxies between z=1.468044 and z=1.506716
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.506716 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.468044)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane28_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 29
# z_lo - z_hi = 1.4307212201781752 1.468043782582634
# found 1547 galaxies between z=1.430721 and z=1.468044
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.468044 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.430721)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane29_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 30
# z_lo - z_hi = 1.394671287030938 1.4307212201781752
# found 2038 galaxies between z=1.394671 and z=1.430721
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.430721 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.394671)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane30_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 31
# z_lo - z_hi = 1.3598241706407883 1.394671287030938
# found 2678 galaxies between z=1.359824 and z=1.394671
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.394671 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.359824)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane31_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 32
# z_lo - z_hi = 1.3261132582931014 1.3598241706407883
# found 3126 galaxies between z=1.326113 and z=1.359824
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.359824 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.326113)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane32_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 33
# z_lo - z_hi = 1.2934802038703366 1.3261132582931014
# found 3319 galaxies between z=1.293480 and z=1.326113
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.326113 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.293480)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane33_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 34
# z_lo - z_hi = 1.2618678199882023 1.2934802038703366
# found 5678 galaxies between z=1.261868 and z=1.293480
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.293480 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.261868)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane34_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 35
# z_lo - z_hi = 1.2312251246850918 1.2618678199882023
# found 5799 galaxies between z=1.231225 and z=1.261868
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.261868 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.231225)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane35_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 36
# z_lo - z_hi = 1.201502260810537 1.2312251246850918
# found 7253 galaxies between z=1.201502 and z=1.231225
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.231225 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.201502)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane36_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 37
# z_lo - z_hi = 1.1726535076448805 1.201502260810537
# found 7232 galaxies between z=1.172654 and z=1.201502
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.201502 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.172654)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane37_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 38
# z_lo - z_hi = 1.1446383402306994 1.1726535076448805
# found 7943 galaxies between z=1.144638 and z=1.172654
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.172654 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.144638)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane38_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 39
# z_lo - z_hi = 1.1174162707803117 1.1446383402306994
# found 7780 galaxies between z=1.117416 and z=1.144638
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.144638 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.117416)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane39_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 40
# z_lo - z_hi = 1.0909509765754253 1.1174162707803117
# found 8607 galaxies between z=1.090951 and z=1.117416
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.117416 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.090951)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane40_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 41
# z_lo - z_hi = 1.0652061909463504 1.0909509765754253
# found 8896 galaxies between z=1.065206 and z=1.090951
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.090951 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.065206)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane41_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 42
# z_lo - z_hi = 1.0401517848032606 1.0652061909463504
# found 9028 galaxies between z=1.040152 and z=1.065206
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.065206 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.040152)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane42_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 43
# z_lo - z_hi = 1.0157546314001553 1.0401517848032606
# found 9122 galaxies between z=1.015755 and z=1.040152
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.040152 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 1.015755)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane43_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 44
# z_lo - z_hi = 0.9919880728679409 1.0157546314001553
# found 9065 galaxies between z=0.991988 and z=1.015755
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 1.015755 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.991988)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane44_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 45
# z_lo - z_hi = 0.9688241482544245 0.9919880728679409
# found 15382 galaxies between z=0.968824 and z=0.991988
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.991988 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.968824)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane45_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 46
# z_lo - z_hi = 0.9462377004616982 0.9688241482544245
# found 15792 galaxies between z=0.946238 and z=0.968824
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.968824 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.946238)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane46_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 47
# z_lo - z_hi = 0.9242046118692109 0.9462377004616982
# found 16561 galaxies between z=0.924205 and z=0.946238
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.946238 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.924205)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane47_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 48
# z_lo - z_hi = 0.9027022129677317 0.9242046118692109
# found 20049 galaxies between z=0.902702 and z=0.924205
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.924205 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.902702)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane48_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 49
# z_lo - z_hi = 0.8817091055011392 0.9027022129677317
# found 19332 galaxies between z=0.881709 and z=0.902702
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.902702 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.881709)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane49_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 50
# z_lo - z_hi = 0.8612052112341263 0.8817091055011392
# found 24086 galaxies between z=0.861205 and z=0.881709
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.881709 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.861205)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane50_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 51
# z_lo - z_hi = 0.8411713067922688 0.8612052112341263
# found 31632 galaxies between z=0.841171 and z=0.861205
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.861205 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.841171)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane51_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 52
# z_lo - z_hi = 0.8215892075708658 0.8411713067922688
# found 30577 galaxies between z=0.821589 and z=0.841171
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.841171 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.821589)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane52_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 53
# z_lo - z_hi = 0.8024418556248318 0.8215892075708658
# found 43710 galaxies between z=0.802442 and z=0.821589
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.821589 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.802442)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane53_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 54
# z_lo - z_hi = 0.7837128414226439 0.8024418556248318
# found 68604 galaxies between z=0.783713 and z=0.802442
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.802442 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.783713)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane54_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 55
# z_lo - z_hi = 0.765386878116552 0.7837128414226439
# found 67055 galaxies between z=0.765387 and z=0.783713
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.783713 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.765387)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane55_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 56
# z_lo - z_hi = 0.7474491021179823 0.765386878116552
# found 65397 galaxies between z=0.747449 and z=0.765387
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.765387 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.747449)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane56_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 57
# z_lo - z_hi = 0.7298856713539662 0.7474491021179823
# found 64188 galaxies between z=0.729886 and z=0.747449
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.747449 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.729886)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane57_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 58
# z_lo - z_hi = 0.7126832956287998 0.7298856713539662
# found 62515 galaxies between z=0.712683 and z=0.729886
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.729886 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.712683)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane58_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 59
# z_lo - z_hi = 0.6958292756061937 0.7126832956287998
# found 61122 galaxies between z=0.695829 and z=0.712683
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.712683 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.695829)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane59_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 60
# z_lo - z_hi = 0.6793117604107808 0.6958292756061937
# found 81620 galaxies between z=0.679312 and z=0.695829
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.695829 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.679312)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane60_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 61
# z_lo - z_hi = 0.6631190969451083 0.6793117604107808
# found 95283 galaxies between z=0.663119 and z=0.679312
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.679312 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.663119)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane61_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 62
# z_lo - z_hi = 0.647240465622943 0.6631190969451083
# found 93169 galaxies between z=0.647240 and z=0.663119
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.663119 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.647240)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane62_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 63
# z_lo - z_hi = 0.6316653478832257 0.647240465622943
# found 91178 galaxies between z=0.631665 and z=0.647240
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.647240 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.631665)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane63_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 64
# z_lo - z_hi = 0.6163838691484912 0.6316653478832257
# found 145548 galaxies between z=0.616384 and z=0.631665
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.631665 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.616384)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane64_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 65
# z_lo - z_hi = 0.6013864434385603 0.6163838691484912
# found 155031 galaxies between z=0.601386 and z=0.616384
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.616384 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.601386)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane65_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 66
# z_lo - z_hi = 0.5866641058099475 0.6013864434385603
# found 151329 galaxies between z=0.586664 and z=0.601386
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.601386 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.586664)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane66_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 67
# z_lo - z_hi = 0.5722081204711477 0.5866641058099475
# found 149186 galaxies between z=0.572208 and z=0.586664
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.586664 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.572208)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane67_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 68
# z_lo - z_hi = 0.5580101380687371 0.5722081204711477
# found 217793 galaxies between z=0.558010 and z=0.572208
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.572208 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.558010)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane68_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 69
# z_lo - z_hi = 0.5440621453914023 0.5580101380687371
# found 234782 galaxies between z=0.544062 and z=0.558010
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.558010 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.544062)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane69_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 70
# z_lo - z_hi = 0.5303566289124714 0.5440621453914023
# found 230376 galaxies between z=0.530357 and z=0.544062
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.544062 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.530357)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane70_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 71
# z_lo - z_hi = 0.5168862769810983 0.5303566289124714
# found 226345 galaxies between z=0.516886 and z=0.530357
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.530357 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.516886)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane71_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 72
# z_lo - z_hi = 0.503644103786733 0.5168862769810983
# found 253758 galaxies between z=0.503644 and z=0.516886
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.516886 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.503644)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane72_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 73
# z_lo - z_hi = 0.49062333167746036 0.503644103786733
# found 296294 galaxies between z=0.490623 and z=0.503644
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.503644 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.490623)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane73_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 74
# z_lo - z_hi = 0.47781757464915176 0.49062333167746036
# found 290183 galaxies between z=0.477818 and z=0.490623
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.490623 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.477818)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane74_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 75
# z_lo - z_hi = 0.4652205717876312 0.47781757464915176
# found 286054 galaxies between z=0.465221 and z=0.477818
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.477818 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.465221)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane75_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 76
# z_lo - z_hi = 0.45282646956380396 0.4652205717876312
# found 281082 galaxies between z=0.452826 and z=0.465221
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.465221 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.452826)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane76_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 77
# z_lo - z_hi = 0.44062951021119307 0.45282646956380396
# found 365880 galaxies between z=0.440630 and z=0.452826
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.452826 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.440630)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane77_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 78
# z_lo - z_hi = 0.4286242504975119 0.44062951021119307
# found 401640 galaxies between z=0.428624 and z=0.440630
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.440630 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.428624)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane78_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 79
# z_lo - z_hi = 0.41680535581629247 0.4286242504975119
# found 396380 galaxies between z=0.416805 and z=0.428624
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.428624 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.416805)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane79_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 80
# z_lo - z_hi = 0.4051678924999039 0.41680535581629247
# found 389436 galaxies between z=0.405168 and z=0.416805
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.416805 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.405168)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane80_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 81
# z_lo - z_hi = 0.3937068361606583 0.4051678924999039
# found 382864 galaxies between z=0.393707 and z=0.405168
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.405168 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.393707)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane81_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 82
# z_lo - z_hi = 0.38241756911901204 0.3937068361606583
# found 366861 galaxies between z=0.382418 and z=0.393707
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.393707 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.382418)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane82_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 83
# z_lo - z_hi = 0.3712955713771242 0.38241756911901204
# found 354022 galaxies between z=0.371296 and z=0.382418
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.382418 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.371296)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane83_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 84
# z_lo - z_hi = 0.36033633480786526 0.3712955713771242
# found 348382 galaxies between z=0.360336 and z=0.371296
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.371296 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.360336)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane84_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 85
# z_lo - z_hi = 0.34953595458531117 0.36033633480786526
# found 344257 galaxies between z=0.349536 and z=0.360336
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.360336 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.349536)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane85_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 86
# z_lo - z_hi = 0.3388901356137989 0.34953595458531117
# found 339482 galaxies between z=0.338890 and z=0.349536
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.349536 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.338890)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane86_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 87
# z_lo - z_hi = 0.3283950717473852 0.3388901356137989
# found 326165 galaxies between z=0.328395 and z=0.338890
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.338890 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.328395)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane87_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 88
# z_lo - z_hi = 0.3180468792244742 0.3283950717473852
# found 209047 galaxies between z=0.318047 and z=0.328395
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.328395 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.318047)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane88_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 89
# z_lo - z_hi = 0.3078421649232703 0.3180468792244742
# found 205149 galaxies between z=0.307842 and z=0.318047
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.318047 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.307842)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane89_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 90
# z_lo - z_hi = 0.2977771444856564 0.3078421649232703
# found 202370 galaxies between z=0.297777 and z=0.307842
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.307842 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.297777)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane90_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 91
# z_lo - z_hi = 0.28784863778470327 0.2977771444856564
# found 199944 galaxies between z=0.287849 and z=0.297777
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.297777 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.287849)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane91_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 92
# z_lo - z_hi = 0.2780532669541748 0.28784863778470327
# found 196789 galaxies between z=0.278053 and z=0.287849
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.287849 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.278053)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane92_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 93
# z_lo - z_hi = 0.2683879530740142 0.2780532669541748
# found 191602 galaxies between z=0.268388 and z=0.278053
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.278053 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.268388)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane93_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 94
# z_lo - z_hi = 0.2588495316317599 0.2683879530740142
# found 147510 galaxies between z=0.258850 and z=0.268388
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.268388 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.258850)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane94_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 95
# z_lo - z_hi = 0.24943502878487617 0.2588495316317599
# found 144530 galaxies between z=0.249435 and z=0.258850
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.258850 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.249435)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane95_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 96
# z_lo - z_hi = 0.2401417762400368 0.24943502878487617
# found 142433 galaxies between z=0.240142 and z=0.249435
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.249435 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.240142)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane96_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 97
# z_lo - z_hi = 0.2309668146427791 0.2401417762400368
# found 142102 galaxies between z=0.230967 and z=0.240142
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.240142 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.230967)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane97_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 98
# z_lo - z_hi = 0.2219075814444402 0.2309668146427791
# found 139267 galaxies between z=0.221908 and z=0.230967
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.230967 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.221908)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane98_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 99
# z_lo - z_hi = 0.21296141556959655 0.2219075814444402
# found 137545 galaxies between z=0.212961 and z=0.221908
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.221908 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.212961)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane99_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 100
# z_lo - z_hi = 0.20412586167957544 0.21296141556959655
# found 104916 galaxies between z=0.204126 and z=0.212961
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.212961 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.204126)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane100_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 101
# z_lo - z_hi = 0.19539836570792812 0.20412586167957544
# found 79746 galaxies between z=0.195398 and z=0.204126
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.204126 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.195398)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane101_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 102
# z_lo - z_hi = 0.18677677613686766 0.19539836570792812
# found 79135 galaxies between z=0.186777 and z=0.195398
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.195398 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.186777)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane102_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 103
# z_lo - z_hi = 0.1782587402606934 0.18677677613686766
# found 77539 galaxies between z=0.178259 and z=0.186777
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.186777 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.178259)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo1_plane103_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 104
# z_lo - z_hi = 0.16984191014824368 0.1782587402606934
# found 76791 galaxies between z=0.169842 and z=0.178259
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.178259 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.169842)
# ...
# Reading in shear 1/2/kappa front (zs = 0.287849)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane91_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 92
# z_lo - z_hi = 0.2780532669541748 0.28784863778470327
# found 18802 galaxies between z=0.278053 and z=0.287849
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.287849 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.278053)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane92_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 93
# z_lo - z_hi = 0.2683879530740142 0.2780532669541748
# found 18296 galaxies between z=0.268388 and z=0.278053
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.278053 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.268388)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane93_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 94
# z_lo - z_hi = 0.2588495316317599 0.2683879530740142
# found 12659 galaxies between z=0.258850 and z=0.268388
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.268388 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.258850)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane94_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 95
# z_lo - z_hi = 0.24943502878487617 0.2588495316317599
# found 12652 galaxies between z=0.249435 and z=0.258850
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.258850 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.249435)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane95_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 96
# z_lo - z_hi = 0.2401417762400368 0.24943502878487617
# found 12656 galaxies between z=0.240142 and z=0.249435
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.249435 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.240142)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane96_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 97
# z_lo - z_hi = 0.2309668146427791 0.2401417762400368
# found 12521 galaxies between z=0.230967 and z=0.240142
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.240142 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.230967)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane97_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 98
# z_lo - z_hi = 0.2219075814444402 0.2309668146427791
# found 12264 galaxies between z=0.221908 and z=0.230967
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.230967 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.221908)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane98_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 99
# z_lo - z_hi = 0.21296141556959655 0.2219075814444402
# found 12127 galaxies between z=0.212961 and z=0.221908
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.221908 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.212961)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane99_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 100
# z_lo - z_hi = 0.20412586167957544 0.21296141556959655
# found 14593 galaxies between z=0.204126 and z=0.212961
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.212961 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.204126)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane100_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 101
# z_lo - z_hi = 0.19539836570792812 0.20412586167957544
# found 17004 galaxies between z=0.195398 and z=0.204126
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.204126 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.195398)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane101_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 102
# z_lo - z_hi = 0.18677677613686766 0.19539836570792812
# found 16555 galaxies between z=0.186777 and z=0.195398
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.195398 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.186777)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane102_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 103
# z_lo - z_hi = 0.1782587402606934 0.18677677613686766
# found 16472 galaxies between z=0.178259 and z=0.186777
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.186777 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.178259)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane103_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 104
# z_lo - z_hi = 0.16984191014824368 0.1782587402606934
# found 16238 galaxies between z=0.169842 and z=0.178259
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.178259 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.169842)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane104_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 105
# z_lo - z_hi = 0.1615243387008066 0.16984191014824368
# found 15633 galaxies between z=0.161524 and z=0.169842
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.169842 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.161524)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane105_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 106
# z_lo - z_hi = 0.15330388172942508 0.1615243387008066
# found 15663 galaxies between z=0.153304 and z=0.161524
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.161524 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.153304)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane106_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 107
# z_lo - z_hi = 0.1451784943912319 0.15330388172942508
# found 12176 galaxies between z=0.145178 and z=0.153304
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.153304 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.145178)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane107_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 108
# z_lo - z_hi = 0.1371461356248949 0.1451784943912319
# found 8172 galaxies between z=0.137146 and z=0.145178
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.145178 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.137146)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane108_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 109
# z_lo - z_hi = 0.1292051641095685 0.1371461356248949
# found 8206 galaxies between z=0.129205 and z=0.137146
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.137146 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.129205)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane109_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 110
# z_lo - z_hi = 0.12135344116261591 0.1292051641095685
# found 8069 galaxies between z=0.121353 and z=0.129205
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.129205 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.121353)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane110_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 111
# z_lo - z_hi = 0.11358942997839946 0.12135344116261591
# found 8061 galaxies between z=0.113589 and z=0.121353
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.121353 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.113589)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane111_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 112
# z_lo - z_hi = 0.10591119334337479 0.11358942997839946
# found 7799 galaxies between z=0.105911 and z=0.113589
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.113589 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.105911)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane112_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 113
# z_lo - z_hi = 0.09831718677127467 0.10591119334337479
# found 7697 galaxies between z=0.098317 and z=0.105911
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.105911 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.098317)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane113_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 114
# z_lo - z_hi = 0.09080570482745227 0.09831718677127467
# found 7559 galaxies between z=0.090806 and z=0.098317
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.098317 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.090806)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane114_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 115
# z_lo - z_hi = 0.08337517718681385 0.09080570482745227
# found 6120 galaxies between z=0.083375 and z=0.090806
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.090806 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.083375)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane115_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 116
# z_lo - z_hi = 0.07602405147766747 0.08337517718681385
# found 5482 galaxies between z=0.076024 and z=0.083375
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.083375 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.076024)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane116_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 117
# z_lo - z_hi = 0.06875082584865816 0.07602405147766747
# found 5446 galaxies between z=0.068751 and z=0.076024
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.076024 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.068751)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane117_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 118
# z_lo - z_hi = 0.06155403276971432 0.06875082584865816
# found 5403 galaxies between z=0.061554 and z=0.068751
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.068751 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.061554)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane118_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 119
# z_lo - z_hi = 0.05443225263269775 0.06155403276971432
# found 5254 galaxies between z=0.054432 and z=0.061554
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.061554 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.054432)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane119_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 120
# z_lo - z_hi = 0.04738409833659879 0.05443225263269775
# found 5202 galaxies between z=0.047384 and z=0.054432
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.054432 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.047384)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane120_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 121
# z_lo - z_hi = 0.04040823354614125 0.04738409833659879
# found 5114 galaxies between z=0.040408 and z=0.047384
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.047384 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.040408)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane121_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 122
# z_lo - z_hi = 0.03350334128262765 0.04040823354614125
# found 5258 galaxies between z=0.033503 and z=0.040408
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.040408 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.033503)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane122_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 123
# z_lo - z_hi = 0.026668168904408512 0.03350334128262765
# found 3311 galaxies between z=0.026668 and z=0.033503
# Found consecutive planes not empty, recycle planes to save IO:
# Recycling map to reduce IO:, zs = 0.033503 was already loaded, now used as back plane
# Reading in shear 1/2/kappa front (zs = 0.026668)
# loaded gamma1
# loaded gamma2
# Wrinting /pscratch/sd/j/jharno/FS//GalCat/RR2_V2/random_pos/GalCat_tomo6_plane123_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# starting analysis of plane 124
# z_lo - z_hi = 0.019901389281033303 0.026668168904408512
# no galaxies here, loop to next plane
# starting analysis of plane 125
# z_lo - z_hi = 0.013201994574778674 0.019901389281033303
# no galaxies here, loop to next plane
# starting analysis of plane 126
# z_lo - z_hi = 0.0065684828696002395 0.013201994574778674
# no galaxies here, loop to next plane
# starting analysis of plane 127
# z_lo - z_hi = 0.0 0.0065684828696002395
# no galaxies here, loop to next plane
# ***************************
# Done writing all catalogues
# ***************************

# %%
# Concatenate catalogues:
import os

if(SkySim):
    print('Concatenating SkySim5000 plane catalogues')
    #os.system("for tomo in {1..1}; do echo 'working on tomo'$tomo; ls -l   /global/homes/j/jharno/IA-infusion/SkySim5000/GalCat/StageIV_nz/*tomo$tomo*0.6GpAM*; done")
    #os.system("for tomo in {1..1}; do cat   /global/homes/j/jharno/IA-infusion/SkySim5000/GalCat/StageIV_nz/*tomo$tomo*0.6GpAM* > /global/homes/j/jharno/IA-infusion/SkySim5000/GalCat/StageIV_nz/GalCat_tomo$tomo'_All_0.6GpAM_RA_Dec_g1_g2_w_z.asc'; done")
    #os.system("for tomo in {5..5}; do echo 'working on tomo'$tomo; ls -l   /global/homes/j/jharno/IA-infusion/SkySim5000/GalCat/StageIV_nz/*tomo$tomo*0.06GpAM_RA_Dec_g1_g2_w_linear_bias.asc; done")
    #os.system("for tomo in {5..5}; do cat   /global/homes/j/jharno/IA-infusion/SkySim5000/GalCat/StageIV_nz/*tomo$tomo*0.06GpAM_RA_Dec_g1_g2_w_linear_bias.asc > /global/homes/j/jharno/IA-infusion/SkySim5000/GalCat/StageIV_nz/V1/GalCat_tomo$tomo'_All_0.06GpAM_RA_Dec_g1_g2_w_z_linear_bias.asc'; done")
    os.system("for tomo in {1..5}; do echo 'working on tomo'$tomo; ls -l   /global/homes/j/jharno/IA-infusion/SkySim5000/GalCat/SRD-Y1/lin_bias_pos/*tomo$tomo*0.6GpAM_RA_Dec_g1_g2_w_linear_bias_smooth01_bta1.asc; done")
    os.system("for tomo in {1..5}; do cat   /global/homes/j/jharno/IA-infusion/SkySim5000/GalCat/SRD-Y1/lin_bias_pos/*tomo$tomo*0.6GpAM_RA_Dec_g1_g2_w_linear_bias_smooth01_bta1.asc > /global/homes/j/jharno/IA-infusion/SkySim5000/GalCat/SRD-Y1/lin_bias_pos/GalCat_tomo$tomo'_All_0.6GpAM_RA_Dec_g1_g2_w_z_linear_bias_smooth01_bta1.asc'; done")

    
if(HACCY1):
    print('Concatenating HACC plane catalogues')
    #GpAM='0.06':
    #os.system("let tomo=5; ls -l   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/StageIV_nz/V0/seed0/*tomo$tomo*nshells19_0.06GpAM*")
    #os.system("let tomo=5; cat   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/StageIV_nz/V0/seed0/*tomo$tomo*nshells19_0.06GpAM* > /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/StageIV_nz/V0/seed0/GalCat_tomo$tomo'_All_nshells19_0.06GpAM_RA_Dec_g1_g2_w_z.asc'")

    #GpAM='0.6':
    #os.system("let tomo=5; ls -l   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/StageIV_nz/V0/seed0/*tomo$tomo*nshells106_0.6GpAM*")
    #os.system("let tomo=5; cat   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/StageIV_nz/V0/seed0/*tomo$tomo*nshells106_0.6GpAM* > /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/StageIV_nz/V0/seed0/GalCat_tomo$tomo'_All_nshells106_0.6GpAM_RA_Dec_g1_g2_w_z.asc'")
    #os.system("for tomo in {1..5}; do  ls -l   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/StageIV_nz/HACC150/V0/seed0/*tomo$tomo*nshells106_0.06GpAM*; done")
    #os.system("for tomo in {1..5}; do cat   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/StageIV_nz/HACC150/V0/seed0/*tomo$tomo*nshells106_0.06GpAM* > /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/StageIV_nz/HACC150/V0/seed0/GalCat_tomo$tomo'_All_nshells106_0.06GpAM_RA_Dec_g1_g2_w_z.asc'; done")
    #os.system("for tomo in {1..5}; do ls -l   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/StageIV_nz/HACC150/V0/seed2/*tomo$tomo*nshells50_0.6GpAM* ; done"); 
    #os.system("for tomo in {1..5}; do cat   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/StageIV_nz/HACC150/V0/seed2/*tomo$tomo*nshells50_0.6GpAM* > /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/StageIV_nz/HACC150/V0/seed2/GalCat_tomo$tomo'_All_nshells50_0.6GpAM_RA_Dec_g1_g2_w_z.asc'; done")
    #os.system("let seed=1; let nshells=27; for tomo in {1..5}; do ls -l /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_2/noIA/seed$seed/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'* ; done"); 
    #os.system("let seed=1; let nshells=27; for tomo in {1..5}; do cat   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_2/noIA/seed$seed/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'* > /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_2/noIA/seed$seed/GalCat_tomo$tomo'_All_nshells'$nshells'_0.6GpAM_RA_Dec_g1_g2_w_z.asc'; done")
    #os.system("let seed=0; let nshells=26; for tomo in {1..5}; do ls -l /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*clmax100.asc ; done"); 
    #os.system("let seed=0; let nshells=26; for tomo in {1..5}; do cat   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*clmax100.asc > /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/GalCat_tomo$tomo'_All_nshells'$nshells'_0.6GpAM_RA_Dec_g1_g2_w_zclmax100.asc'; done")
    #os.system("let seed=0; let nshells=26; for tomo in {1..5}; do ls -l /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*nosubsample.asc ; done"); 
    #os.system("let seed=0; let nshells=26; for tomo in {1..5}; do cat   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*nosubsample.asc > /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/GalCat_tomo$tomo'_All_nshells'$nshells'_0.6GpAM_RA_Dec_g1_g2_w_z_nosubsample.asc'; done")
    #os.system("let seed=0; let nshells=106; for tomo in {1..5}; do ls -l /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150/noIA/seed$seed/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'* ; done"); 
    #os.system("let seed=0; let nshells=106; for tomo in {1..5}; do cat   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150/noIA/seed$seed/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'* > /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150/noIA/seed$seed/GalCat_tomo$tomo'_All_nshells'$nshells'_0.6GpAM_RA_Dec_g1_g2_w_z.asc'; done")
    #os.system("let seed=0; let nshells=26; for tomo in {1..5}; do ls -l /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*subsampledensitymax_nside8192.asc ; done"); 
    #os.system("let seed=0; let nshells=26; for tomo in {1..5}; do cat   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*subsampledensitymax_nside8192.asc > /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/GalCat_tomo$tomo'_All_nshells'$nshells'_0.6GpAM_RA_Dec_g1_g2_w_z_subsampledensitymax_nside8192.asc'; done")
    #os.system("let seed=0; let nshells=26; for tomo in {1..5}; do ls -l /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*nosubsample_nside8192.asc ; done"); 
    #os.system("let seed=0; let nshells=26; for tomo in {1..5}; do cat   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*nosubsample_nside8192.asc > /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/GalCat_tomo$tomo'_All_nshells'$nshells'_0.6GpAM_RA_Dec_g1_g2_w_z_nosubsample_nside8192.asc'; done")
    #os.system("let seed=0; let nshells=101; for tomo in {1..5}; do ls -l /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*subsampledensitymax_nside8192.asc ; done"); 
    #os.system("let seed=0; let nshells=101; for tomo in {1..5}; do cat   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*subsampledensitymax_nside8192.asc > /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/GalCat_tomo$tomo'_All_nshells'$nshells'_0.6GpAM_RA_Dec_g1_g2_w_z_subsampledensitymax_nside8192.asc'; done")
    #os.system("let seed=0; let nshells=101; for tomo in {1..5}; do ls -l /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*subsampledensitymax_nside8192_linear_bias_bta2.asc ; done"); 
    #os.system("let seed=0; let nshells=101; for tomo in {1..5}; do cat   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*subsampledensitymax_nside8192_linear_bias_bta2.asc > /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/GalCat_tomo$tomo'_All_nshells'$nshells'_0.6GpAM_RA_Dec_g1_g2_w_z_subsampledensitymax_nside8192_linear_bias_bta2.asc'; done")
    #os.system("let seed=0; let nshells=101; for tomo in {1..5}; do ls -l /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*subsampledensitymax_nside8192_linear_bias.asc ; done"); 
    #os.system("let seed=0; let nshells=101; for tomo in {1..5}; do cat   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*subsampledensitymax_nside8192_linear_bias.asc > /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/GalCat_tomo$tomo'_All_nshells'$nshells'_0.6GpAM_RA_Dec_g1_g2_w_z_subsampledensitymax_nside8192_linear_bias.asc'; done")

    #BCM:
    os.system("let seed=0; let nshells=51; tracer=''; model='dmo'; for tomo in {1..5}; do ls -l /global/homes/j/jharno/IA-infusion/BCM/$model/GalCat/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*z$tracer.asc ; done"); 
    os.system("let seed=0; let nshells=51; tracer=''; model='dmo'; for tomo in {1..5}; do cat   /global/homes/j/jharno/IA-infusion/BCM/$model/GalCat/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*z$tracer.asc > /global/homes/j/jharno/IA-infusion/BCM/$model/GalCat/GalCat_tomo$tomo'_All_nshells'$nshells'_0.6GpAM_RA_Dec_g1_g2_w_z'$tracer'.asc'; done")
    #os.system("let seed=0; let nshells=51; tracer='_linear_bias'; model='dmo'; for tomo in {1..5}; do ls -l /global/homes/j/jharno/IA-infusion/BCM/$model/GalCat/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*z$tracer.asc ; done"); 
    #os.system("let seed=0; let nshells=51; tracer='_linear_bias'; model='dmo'; for tomo in {1..5}; do cat   /global/homes/j/jharno/IA-infusion/BCM/$model/GalCat/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*z$tracer.asc > /global/homes/j/jharno/IA-infusion/BCM/$model/GalCat/GalCat_tomo$tomo'_All_nshells'$nshells'_0.6GpAM_RA_Dec_g1_g2_w_z'$tracer'.asc'; done")
    #os.system("let seed=0; let nshells=51; for tomo in {1..5}; do ls -l /global/homes/j/jharno/IA-infusion/BCM/dmo/GalCat/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*z.asc ; done"); 
    #os.system("let seed=0; let nshells=51; for tomo in {1..5}; do cat   /global/homes/j/jharno/IA-infusion/BCM/dmo/GalCat/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*z.asc > /global/homes/j/jharno/IA-infusion/BCM/dmo/GalCat/GalCat_tomo$tomo'_All_nshells'$nshells'_0.6GpAM_RA_Dec_g1_g2_w_z.asc'; done")
    #os.system("let seed=0; let nshells=51; for tomo in {1..5}; do ls -l /global/homes/j/jharno/IA-infusion/BCM/dmb_Mc5e13/GalCat/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*z.asc ; done"); 
    #os.system("let seed=0; let nshells=51; for tomo in {1..5}; do cat   /global/homes/j/jharno/IA-infusion/BCM/dmb_Mc5e13/GalCat/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*z.asc > /global/homes/j/jharno/IA-infusion/BCM/dmb_Mc5e13/GalCat/GalCat_tomo$tomo'_All_nshells'$nshells'_0.6GpAM_RA_Dec_g1_g2_w_z.asc'; done")
    #os.system("let seed=0; let nshells=51; for tomo in {1..5}; do ls -l /global/homes/j/jharno/IA-infusion/BCM/dmb_theta_ej_6/GalCat/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*z.asc ; done"); 
    #os.system("let seed=0; let nshells=51; for tomo in {1..5}; do cat   /global/homes/j/jharno/IA-infusion/BCM/dmb_theta_ej_6/GalCat/*tomo$tomo*plane*nshells$nshells'_0.6GpAM'*z.asc > /global/homes/j/jharno/IA-infusion/BCM/dmb_theta_ej_6/GalCat/GalCat_tomo$tomo'_All_nshells'$nshells'_0.6GpAM_RA_Dec_g1_g2_w_z.asc'; done")


if(FS):
    print('Concatenating FS plane catalogues')
    #os.system("for tomo in {1..1}; do echo 'working on tomo'$tomo; ls -l   /global/homes/j/jharno/IA-infusion/SkySim5000/GalCat/StageIV_nz/*tomo$tomo*0.6GpAM*; done")
    #os.system("for tomo in {1..1}; do cat   /global/homes/j/jharno/IA-infusion/SkySim5000/GalCat/StageIV_nz/*tomo$tomo*0.6GpAM* > /global/homes/j/jharno/IA-infusion/SkySim5000/GalCat/StageIV_nz/GalCat_tomo$tomo'_All_0.6GpAM_RA_Dec_g1_g2_w_z.asc'; done")
    #os.system("for tomo in {5..5}; do echo 'working on tomo'$tomo; ls -l   /global/homes/j/jharno/IA-infusion/SkySim5000/GalCat/StageIV_nz/*tomo$tomo*0.06GpAM_RA_Dec_g1_g2_w_linear_bias.asc; done")
    #os.system("for tomo in {5..5}; do cat   /global/homes/j/jharno/IA-infusion/SkySim5000/GalCat/StageIV_nz/*tomo$tomo*0.06GpAM_RA_Dec_g1_g2_w_linear_bias.asc > /global/homes/j/jharno/IA-infusion/SkySim5000/GalCat/StageIV_nz/V1/GalCat_tomo$tomo'_All_0.06GpAM_RA_Dec_g1_g2_w_z_linear_bias.asc'; done")
    os.system("for tomo in {1..6}; do echo 'working on tomo'$tomo; ls -l   /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/*tomo$tomo*0.6GpAM_RA_Dec_g1_g2_w_z.asc; done")
    os.system("for tomo in {1..6}; do cat   /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/*tomo$tomo*0.6GpAM_RA_Dec_g1_g2_w_z.asc > /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo$tomo'_All_0.6GpAM_RA_Dec_g1_g2_w_z.asc'; done")
# Out:
# Concatenating FS plane catalogues
# working on tomo1
# -rw-rw---- 1 jharno jharno 15822901 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane100_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1538163 May 19 08:47 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane10_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 11959703 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane101_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 11852178 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane102_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 11741181 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane103_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 11624157 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane104_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 11428850 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane105_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 11317839 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane106_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  8233225 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane107_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4816878 May 19 08:51 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane108_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4764997 May 19 08:51 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane109_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4725138 May 19 08:51 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane110_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1206886 May 19 08:47 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane11_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4669195 May 19 08:51 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane111_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4594794 May 19 08:51 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane112_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4582372 May 19 08:51 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane113_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4476861 May 19 08:51 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane114_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2443899 May 19 08:51 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane115_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1762041 May 19 08:51 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane116_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1784642 May 19 08:51 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane117_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1733382 May 19 08:51 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane118_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1716718 May 19 08:51 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane119_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1695882 May 19 08:51 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane120_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   662750 May 19 08:47 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane12_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1657037 May 19 08:51 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane121_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1668221 May 19 08:51 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane122_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1063609 May 19 08:51 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane123_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   718952 May 19 08:47 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane13_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   576393 May 19 08:47 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane14_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   547192 May 19 08:47 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane15_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   494716 May 19 08:47 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane16_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   677361 May 19 08:47 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane17_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   496070 May 19 08:47 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane18_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   414154 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane19_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   282877 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane20_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   436405 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane21_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   236453 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane22_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   320434 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane23_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   330824 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane24_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   259890 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane25_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   307108 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane26_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   412016 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane27_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   503783 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane28_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   225124 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane29_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   294179 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane30_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   379438 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane31_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   479049 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane32_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   483213 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane33_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   869920 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane34_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   884686 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane35_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1131421 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane36_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1103839 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane37_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1173078 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane38_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1167483 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane39_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1313337 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane40_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1334481 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane41_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1360275 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane42_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1386378 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane43_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1362730 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane44_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2332647 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane45_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2414677 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane46_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2485840 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane47_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2972792 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane48_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2926547 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane49_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  3624254 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane50_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   954666 May 19 08:47 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane5_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4772066 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane51_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4657039 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane52_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  6647752 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane53_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 10252191 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane54_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 10095060 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane55_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  9870889 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane56_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  9603364 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane57_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  9459509 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane58_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  9218103 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane59_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 12303819 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane60_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  3531039 May 19 08:47 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane6_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 14298204 May 19 08:48 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane61_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 14022077 May 19 08:49 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane62_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 13788602 May 19 08:49 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane63_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 22060400 May 19 08:49 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane64_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 23450536 May 19 08:49 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane65_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 22948420 May 19 08:49 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane66_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 22622731 May 19 08:49 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane67_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 32972729 May 19 08:49 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane68_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 35487666 May 19 08:49 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane69_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 34780312 May 19 08:49 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane70_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2406462 May 19 08:47 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane7_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 34117829 May 19 08:49 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane71_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 38317553 May 19 08:49 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane72_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 44664845 May 19 08:49 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane73_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 43874355 May 19 08:49 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane74_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 43246969 May 19 08:49 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane75_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 42541519 May 19 08:49 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane76_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 55501089 May 19 08:49 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane77_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 60592925 May 19 08:49 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane78_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 59678347 May 19 08:49 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane79_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 58844230 May 19 08:49 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane80_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1952325 May 19 08:47 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane8_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 57857577 May 19 08:49 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane81_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 55328446 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane82_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 53437886 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane83_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 52693402 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane84_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 51932902 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane85_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 51230780 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane86_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 49413736 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane87_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 31530720 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane88_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 31077743 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane89_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 30532415 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane90_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1526885 May 19 08:47 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane9_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 30185827 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane91_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 29814040 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane92_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 28851616 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane93_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 22177065 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane94_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 21766466 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane95_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 21582443 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane96_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 21303073 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane97_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 20992544 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane98_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 20840283 May 19 08:50 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane99_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# working on tomo2
# -rw-rw---- 1 jharno jharno  8370972 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane100_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   843458 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane10_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  6035620 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane101_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  6043693 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane102_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  5939134 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane103_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  5888775 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane104_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  5814313 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane105_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  5706001 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane106_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4242089 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane107_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2545037 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane108_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2502996 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane109_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2485077 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane110_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   623505 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane11_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2461009 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane111_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2432143 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane112_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2395567 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane113_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2399031 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane114_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1499979 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane115_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1208605 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane116_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1198535 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane117_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1155156 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane118_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1182223 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane119_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1181037 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane120_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   461141 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane12_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1152995 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane121_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1131140 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane122_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   743430 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane123_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   418898 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane13_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   341887 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane14_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   364873 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane15_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   403372 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane16_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   494521 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane17_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   419368 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane18_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   353661 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane19_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   501186 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane20_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1024423 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane21_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   443955 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane22_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   634519 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane23_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   576285 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane24_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   339315 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane25_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   264080 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane26_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   630584 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane27_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   914581 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane28_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   560241 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane29_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   532930 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane30_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   509084 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane31_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   665272 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane32_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   714203 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane33_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1673385 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane34_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1824477 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane35_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1650244 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane36_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1623397 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane37_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2352330 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane38_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2381922 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane39_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2810269 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane40_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2910521 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane41_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  3386931 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane42_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4248356 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane43_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4141001 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane44_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  6491799 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane45_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  6702486 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane46_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  7389422 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane47_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 10066542 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane48_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  9731303 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane49_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 11255607 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane50_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   631197 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane5_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 13657413 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane51_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 13335243 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane52_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 18112565 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane53_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 27347631 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane54_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 26738032 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane55_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 26980911 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane56_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 34097887 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane57_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 33470471 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane58_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 32690239 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane59_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 37608343 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane60_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2264114 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane6_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 40696859 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane61_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 40000270 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane62_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 39294433 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane63_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 46879713 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane64_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 47717347 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane65_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 46783117 May 19 08:55 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane66_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 45985674 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane67_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 51411786 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane68_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 52111421 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane69_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 51373902 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane70_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1660813 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane7_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 50478311 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane71_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 47336608 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane72_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 43338489 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane73_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 42459933 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane74_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 41969265 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane75_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 41197239 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane76_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 36587252 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane77_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 34178862 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane78_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 33600154 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane79_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 32946952 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane80_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1257121 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane8_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 32498295 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane81_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 31136010 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane82_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 29975039 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane83_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 29736818 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane84_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 29338207 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane85_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 28968177 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane86_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 27827789 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane87_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 16640488 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane88_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 16442154 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane89_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 16226096 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane90_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   887577 May 19 08:54 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane9_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 15988652 May 19 08:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane91_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 15773679 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane92_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 15392217 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane93_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 11964562 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane94_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 11808727 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane95_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 11602623 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane96_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 11526172 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane97_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 11363809 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane98_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 11210473 May 19 08:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane99_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# working on tomo3
# -rw-rw---- 1 jharno jharno  5627055 May 19 09:00 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane100_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1222184 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane10_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4858833 May 19 09:00 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane101_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4801003 May 19 09:00 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane102_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4742506 May 19 09:00 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane103_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4704114 May 19 09:01 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane104_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4583430 May 19 09:01 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane105_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4605958 May 19 09:01 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane106_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  3334363 May 19 09:01 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane107_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2061487 May 19 09:01 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane108_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2015591 May 19 09:01 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane109_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2021083 May 19 09:01 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane110_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1060019 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane11_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1991951 May 19 09:01 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane111_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2002782 May 19 09:01 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane112_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1936530 May 19 09:01 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane113_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1946146 May 19 09:01 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane114_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1092651 May 19 09:01 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane115_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   839500 May 19 09:01 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane116_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   818419 May 19 09:01 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane117_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   804324 May 19 09:01 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane118_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   799599 May 19 09:01 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane119_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   791145 May 19 09:01 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane120_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   777851 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane12_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   797822 May 19 09:01 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane121_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   776029 May 19 09:01 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane122_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   506755 May 19 09:01 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane123_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   756611 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane13_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   567079 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane14_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   680577 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane15_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   528827 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane16_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   554025 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane17_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   571725 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane18_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   573497 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane19_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   646150 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane20_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1227353 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane21_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   708743 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane22_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   821924 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane23_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   810983 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane24_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   680152 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane25_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   644700 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane26_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1090045 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane27_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1427713 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane28_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1216992 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane29_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1316168 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane30_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1503143 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane31_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1524636 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane32_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1532629 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane33_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  3573878 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane34_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  3855787 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane35_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4036409 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane36_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  3980944 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane37_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  6636365 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane38_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  6784634 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane39_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  8582127 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane40_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  9283103 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane41_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 12331115 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane42_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 17993801 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane43_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 17325159 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane44_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 30220899 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane45_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 31380417 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane46_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 33044114 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane47_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 40779273 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane48_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 39835257 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane49_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 45404418 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane50_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   599453 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane5_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 55007607 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane51_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 53499991 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane52_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 58917846 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane53_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 70018129 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane54_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 68400772 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane55_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 66046236 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane56_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 56095633 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane57_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 55071312 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane58_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 53723741 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane59_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 51048690 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane60_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2134202 May 19 08:58 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane6_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 48845927 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane61_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 47940777 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane62_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 46956174 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane63_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 40751398 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane64_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 38950970 May 19 08:59 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane65_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 38202851 May 19 09:00 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane66_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# ...
# -rw-rw---- 1 jharno jharno 51929910 May 19 09:08 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane11_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1178455 May 19 09:11 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane111_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1175582 May 19 09:11 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane112_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1162194 May 19 09:11 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane113_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1153100 May 19 09:11 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane114_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   898167 May 19 09:11 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane115_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   824138 May 19 09:11 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane116_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   791974 May 19 09:11 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane117_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   814760 May 19 09:11 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane118_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   794135 May 19 09:11 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane119_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   787935 May 19 09:11 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane120_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 50954314 May 19 09:08 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane12_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   787552 May 19 09:11 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane121_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   768465 May 19 09:11 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane122_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno   506409 May 19 09:11 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane123_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 51131013 May 19 09:08 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane13_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 51770411 May 19 09:08 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane14_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 53910807 May 19 09:08 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane15_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 55254808 May 19 09:08 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane16_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 57033378 May 19 09:08 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane17_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 60381397 May 19 09:08 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane18_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 66150204 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane19_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 65548873 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane20_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 63048746 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane21_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 59653156 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane22_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 57035368 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane23_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 55711379 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane24_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 55438798 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane25_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 54310305 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane26_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 53811301 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane27_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 52374660 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane28_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 42585871 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane29_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 35038644 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane30_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 24509297 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane31_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 23157943 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane32_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 22016711 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane33_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 18813899 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane34_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 17657999 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane35_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 14925905 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane36_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 14377973 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane37_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 14463253 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane38_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 13942761 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane39_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 11605574 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane40_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 10381984 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane41_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  9864701 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane42_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  9110392 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane43_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  8833173 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane44_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  6541392 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane45_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  6100314 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane46_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  5873523 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane47_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  5786320 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane48_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  5633868 May 19 09:09 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane49_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  5678708 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane50_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4260004 May 19 09:08 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane5_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  5780808 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane51_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  5593754 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane52_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  5457072 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane53_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  5229544 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane54_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  5120606 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane55_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4978432 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane56_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4319733 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane57_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4267425 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane58_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  4184221 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane59_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  3098002 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane60_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 20551947 May 19 09:08 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane6_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2443889 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane61_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2399044 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane62_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2352175 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane63_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2357358 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane64_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2358157 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane65_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2342332 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane66_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2271185 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane67_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1599751 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane68_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1378211 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane69_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1354869 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane70_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 23598446 May 19 09:08 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane7_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1341807 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane71_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1448824 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane72_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1627705 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane73_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1585887 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane74_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1509172 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane75_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1497233 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane76_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2325347 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane77_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2707708 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane78_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2631328 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane79_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2564127 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane80_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 34004053 May 19 09:08 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane8_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2530018 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane81_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2107271 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane82_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1855500 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane83_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1798367 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane84_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1758718 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane85_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1768912 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane86_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1830136 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane87_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  3016989 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane88_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2922865 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane89_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2946754 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane90_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 41341973 May 19 09:08 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane9_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2887213 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane91_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2839469 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane92_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  2741713 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane93_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1936495 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane94_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1931948 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane95_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1909027 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane96_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1886054 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane97_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1874147 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane98_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno  1819599 May 19 09:10 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane99_0.6GpAM_RA_Dec_g1_g2_w_z.asc

# %%
#!ls -l /global/homes/j/jharno/IA-infusion/BCM/dmo/GalCat/*All*
# !ls -l /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/*All*
# Out:
# -rw-rw---- 1 jharno jharno 1681874986 May 19 11:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_All_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 1681897022 May 19 11:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_All_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 1681913601 May 19 11:56 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_All_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 1681926171 May 19 11:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_All_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 1681929580 May 19 11:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_All_0.6GpAM_RA_Dec_g1_g2_w_z.asc
# -rw-rw---- 1 jharno jharno 1681922763 May 19 11:57 /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_All_0.6GpAM_RA_Dec_g1_g2_w_z.asc

# %%
# Clean up catalogues for boundary effects, where shear is sometimes -1e30...
# Must run after concatenating the plane catalogues
seed=0
nshells=51
GpAM = 0.6
if(HACCY1):
    #HACC
    #path='/global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/StageIV_nz/HACC150/V0/seed'+str(seed)+'/'
    #path='/global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_2/noIA/seed'+str(seed)+'/'
    #path='/global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed'+str(seed)+'/'
    #path='/global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150/noIA/seed'+str(seed)+'/'
    
    #BCM:
    path='/global/homes/j/jharno/IA-infusion/BCM/dmo/GalCat/'
    
    for tomo in range(1,2):
        
        #HACC:
        #fname_in='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z.asc'
        #fname_out='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_good.asc'
        #fname_in='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_nosubsample.asc'
        #fname_out='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_good_nosubsample.asc'
        #fname_in='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_zclmax100.asc'
        #fname_out='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_good_clmax100.asc'
        #fname_in='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_subsampledensitymax_nside8192.asc'
        #fname_out='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_good_subsampledensitymax_nside8192.asc'
        #fname_in='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_nosubsample_nside8192.asc'
        #fname_out='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_good_nosubsample_nside8192.asc'
        #fname_in='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_subsampledensitymax_nside8192_linear_bias.asc'
        #fname_out='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_good_subsampledensitymax_nside8192_linear_bias.asc'
        #fname_in='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_subsampledensitymax_nside8192_linear_bias_bta2.asc'
        #fname_out='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_good_subsampledensitymax_nside8192_linear_bias_bta2.asc'

        #BCM:
        fname_in='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(GpAM)+'GpAM_RA_Dec_g1_g2_w_z.asc'
        fname_out='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(GpAM)+'GpAM_RA_Dec_g1_g2_w_z_good.asc'
        
        GalCat = np.loadtxt(path+fname_in)
        Good_cat = GalCat[GalCat[:,3]>-1]
        veryGood_cat = Good_cat[Good_cat[:,3]<10]
        np.savetxt(path+fname_out,veryGood_cat)

        Bad_cat = GalCat[GalCat[:,3]<-1]
        veryBad_cat = Bad_cat[Bad_cat[:,3]>10]

        print("Removed "+str(np.shape(veryBad_cat)[0])+" bad galaxies")
        print('Cleaned GalCat for tomo',tomo)
# Out:
# Removed 0 bad galaxies
# Cleaned GalCat for tomo 1

# %%
# Clean up catalogues for boundary effects, where shear is sometimes -1e30...
# Must run after concatenating the plane catalogues
seed=0
nshells=51
if(HACCY1):
    #path='/global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/StageIV_nz/HACC150/V0/seed'+str(seed)+'/'
    #path='/global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_2/noIA/seed'+str(seed)+'/'
    #path='/global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed'+str(seed)+'/'
    #path='/global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150/noIA/seed'+str(seed)+'/'

    #BCM:
    path='/global/homes/j/jharno/IA-infusion/BCM/dmb/GalCat/'

    
    for tomo in range(1,6):
        #fname_in='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z.asc'
        #fname_out='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_good.asc'
        #fname_in='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_nosubsample.asc'
        #fname_out='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_good_nosubsample.asc'
        #fname_in='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_zclmax100.asc'
        #fname_out='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_good_clmax100.asc'
        #fname_in='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_subsampledensitymax_nside8192.asc'
        #fname_out='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_good_subsampledensitymax_nside8192.asc'
        #fname_in='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_nosubsample_nside8192.asc'
        #fname_out='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_good_nosubsample_nside8192.asc'
        #fname_in='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_good_subsampledensitymax_nside8192_linear_bias.asc'
        #fname_out='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(gpam)+'GpAM_RA_Dec_g1_g2_w_z_verygood_subsampledensitymax_nside8192_linear_bias.asc'

        #BCM:
        fname_in='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(GpAM)+'GpAM_RA_Dec_g1_g2_w_z.asc'
        fname_out='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(GpAM)+'GpAM_RA_Dec_g1_g2_w_z_good.asc'

        GalCat = np.loadtxt(path+fname_in)
        Good_cat = GalCat[GalCat[:,3]<10]
        np.savetxt(path+fname_out,Good_cat)
        Bad_cat = GalCat[GalCat[:,3]>1]
        print("Removed "+str(np.shape(Bad_cat)[0])+" bad galaxies")
        print('Cleaned GalCat for tomo',tomo)
# Out:
# Removed 0 bad galaxies
# Cleaned GalCat for tomo 1
# Removed 0 bad galaxies
# Cleaned GalCat for tomo 2
# Removed 0 bad galaxies
# Cleaned GalCat for tomo 3
# Removed 0 bad galaxies
# Cleaned GalCat for tomo 4
# Removed 0 bad galaxies
# Cleaned GalCat for tomo 5

# %%
# Remove temporary products
#os.system("ls -l   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/StageIV_nz/HACC150/V0/seed1/*plane*")
#os.system("cat     /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/StageIV_nz/HACC150/V0/seed1/*plane*")
# Might not always work on jupyter notebook, as it involves too much data being erased, clean up in terminal instead...

# clean up the un-good galaxy products:
#os.system("let seed=2;rm -v   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/StageIV_nz/HACC150/V0/seed$seed/*g1_g2_w_z.asc")
#os.system("let seed=1;rm -v   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/*plane*")
#os.system("let seed=0;rm -v   /global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed$seed/*plane*")
#os.system("rm -v   /global/homes/j/jharno/IA-infusion/BCM/dmo/GalCat/*plane*")
#os.system("rm -v   /global/homes/j/jharno/IA-infusion/BCM/dmb_theta_ej_6/GalCat/*plane*")
#os.system("rm -v   /global/homes/j/jharno/IA-infusion/BCM/dmb_theta_ej_6/GalCat/*plane*")
os.system("rm -v   /pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/*plane*")
# Out:
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane100_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane10_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane101_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane102_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane103_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane104_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane105_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane106_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane107_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane108_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane109_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane110_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane11_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane111_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane112_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane113_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane114_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane115_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane116_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane117_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane118_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane119_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane120_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane12_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane121_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane122_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane123_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane13_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane14_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane15_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane16_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane17_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane18_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane19_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane20_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane21_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane22_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane23_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane24_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane25_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane26_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane27_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane28_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane29_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane30_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane31_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane32_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane33_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane34_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane35_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane36_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane37_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane38_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane39_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane40_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane41_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane42_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane43_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane44_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane45_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane46_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane47_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane48_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane49_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane50_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane5_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane51_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane52_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane53_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane54_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane55_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane56_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane57_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane58_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane59_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane60_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane6_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane61_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane62_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane63_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane64_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane65_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane66_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane67_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane68_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane69_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane70_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane7_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane71_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane72_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane73_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane74_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane75_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane76_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane77_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane78_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane79_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane80_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane8_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane81_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane82_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane83_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane84_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane85_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane86_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane87_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane88_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane89_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane90_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane9_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane91_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane92_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane93_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane94_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane95_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane96_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane97_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane98_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo1_plane99_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane100_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane10_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane101_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane102_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane103_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane104_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane105_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane106_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane107_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane108_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane109_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane110_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane11_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane111_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane112_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane113_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane114_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane115_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane116_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane117_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane118_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane119_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane120_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane12_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane121_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane122_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane123_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane13_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane14_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane15_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane16_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane17_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane18_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane19_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane20_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane21_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane22_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane23_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane24_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane25_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane26_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane27_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane28_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane29_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane30_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane31_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane32_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane33_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane34_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane35_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane36_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane37_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane38_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane39_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane40_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane41_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane42_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane43_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane44_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane45_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane46_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane47_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane48_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane49_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane50_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane5_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane51_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane52_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane53_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane54_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane55_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane56_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane57_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane58_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane59_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane60_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane6_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane61_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane62_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane63_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane64_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane65_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane66_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane67_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane68_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane69_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane70_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane7_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane71_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane72_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane73_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane74_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane75_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane76_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane77_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane78_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane79_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane80_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane8_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane81_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane82_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane83_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane84_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane85_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane86_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane87_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane88_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane89_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane90_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane9_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane91_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane92_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane93_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane94_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane95_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane96_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane97_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane98_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo2_plane99_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane100_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane10_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane101_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane102_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane103_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane104_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane105_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane106_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane107_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane108_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane109_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane110_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane11_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane111_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane112_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane113_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane114_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane115_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane116_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane117_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane118_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane119_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane120_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane12_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane121_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane122_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane123_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane13_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane14_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane15_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane16_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane17_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane18_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane19_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane20_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane21_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane22_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane23_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane24_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane25_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane26_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane27_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane28_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane29_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane30_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane31_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane32_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane33_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane34_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane35_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane36_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane37_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane38_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane39_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane40_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane41_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane42_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane43_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane44_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane45_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane46_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane47_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane48_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane49_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane50_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane5_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane51_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane52_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane53_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane54_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane55_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane56_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane57_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane58_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane59_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane60_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane6_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane61_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane62_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane63_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane64_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane65_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane66_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane67_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane68_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane69_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane70_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane7_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane71_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane72_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane73_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane74_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane75_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane76_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane77_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane78_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane79_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane80_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane8_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane81_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane82_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane83_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane84_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane85_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane86_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane87_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane88_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane89_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane90_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane9_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane91_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane92_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane93_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane94_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane95_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane96_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane97_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane98_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo3_plane99_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane100_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane10_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane101_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane102_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane103_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane104_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane105_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane106_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane107_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane108_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane109_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane110_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane11_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane111_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane112_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane113_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane114_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane115_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane116_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane117_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane118_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane119_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane120_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane12_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane121_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane122_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane123_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane13_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane14_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane15_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane16_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane17_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane18_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane19_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane20_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane21_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane22_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane23_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane24_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane25_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane26_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane27_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane28_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane29_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane30_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane31_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane32_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane33_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane34_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane35_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane36_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane37_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane38_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane39_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane40_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane41_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane42_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane43_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane44_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane45_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane46_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane47_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane48_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane49_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane50_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane5_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane51_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane52_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane53_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane54_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane55_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane56_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane57_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane58_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane59_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane60_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane6_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo4_plane61_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# ...
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane76_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane77_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane78_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane79_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane80_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane8_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane81_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane82_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane83_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane84_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane85_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane86_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane87_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane88_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane89_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane90_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane9_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane91_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane92_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane93_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane94_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane95_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane96_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane97_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane98_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo5_plane99_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane100_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane10_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane101_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane102_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane103_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane104_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane105_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane106_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane107_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane108_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane109_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane110_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane11_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane111_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane112_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane113_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane114_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane115_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane116_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane117_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane118_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane119_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane120_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane12_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane121_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane122_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane123_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane13_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane14_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane15_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane16_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane17_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane18_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane19_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane20_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane21_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane22_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane23_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane24_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane25_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane26_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane27_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane28_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane29_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane30_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane31_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane32_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane33_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane34_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane35_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane36_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane37_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane38_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane39_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane40_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane41_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane42_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane43_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane44_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane45_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane46_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane47_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane48_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane49_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane50_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane5_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane51_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane52_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane53_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane54_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane55_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane56_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane57_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane58_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane59_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane60_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane6_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane61_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane62_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane63_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane64_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane65_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane66_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane67_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane68_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane69_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane70_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane7_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane71_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane72_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane73_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane74_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane75_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane76_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane77_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane78_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane79_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane80_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane8_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane81_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane82_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane83_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane84_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane85_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane86_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane87_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane88_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane89_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane90_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane9_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane91_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane92_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane93_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane94_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane95_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane96_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane97_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane98_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# removed '/pscratch/sd/j/jharno/FS/GalCat/RR2_V2/random_pos/GalCat_tomo6_plane99_0.6GpAM_RA_Dec_g1_g2_w_z.asc'
# 0

# %%
# Visualise HACC-Y1 catalogue
seed = 0
GpAM='0.6'
#path='/global/homes/j/jharno/IA-infusion/HACC-Y1/GalCat/SRD-Y1/HACC150_3/noIA/seed'+str(seed)+'/'
path = '/global/homes/j/jharno/IA-infusion/BCM/dmo/GalCat/'
for tomo in range(1,2):
    #fname_in='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+GpAM+'GpAM_RA_Dec_g1_g2_w_z_good_subsampledensitymax_nside8192_linear_bias.asc'
    fname_in='GalCat_tomo'+str(tomo)+'_All_nshells'+str(nshells)+'_'+str(GpAM)+'GpAM_RA_Dec_g1_g2_w_z.asc'
    GalCat = np.loadtxt(path+fname_in)
    
    hp.mollview()
    hp.projscatter(GalCat[:,0],GalCat[:,1], lonlat=True)
    plt.show()

# %%
plane=33
#fname = path_in+'density_map_'+str(snaplist[plane])+'_dens.bin'
fname = '/pscratch/sd/a/avijit97/BCM/HACC/params_dependencies/full_lightcone/Mc/2e14/nshells_51/nshells_51_imap_{}/baryonified_shells_v11.h5'.format(plane)


print('Working on file '+fname)
tmp = np.fromfile(fname,'<f')

# Format is nested, order into ring in order to use alm2maps transforms
# and degrade NSIDE 
#print("NSIDE_orig=", hp.get_nside(tmp))
#binmap=hp.pixelfunc.ud_grade(tmp, 4096, pess=False, order_in='NESTED', order_out='RING', power=None, dtype=None)
#print("NSIDE_new=", hp.get_nside(binmap))

# Or reorder, keeping all full NSIDE resolution
hpmap_density = hp.reorder(tmp, n2r = True)
del tmp
hp.mollview(hpmap_density, nest=False)
plt.show()


# Visualise map
lonra = [0, 2]
latra = [0, 1]
hp.cartview(hpmap_density,
    cbar=True, lonra=lonra, latra=latra,
    nest=False,
    title=" ",
    # min=-10, max=0,
    cmap=plt.cm.coolwarm,
    norm=None, unit='delta')
#plt.show()

# %%
#lonra = [0, 2]
#latra = [0, 1]
#GpAM='0.06'
pathNLA='/global/homes/j/jharno/IA-infusion/SkySim5000/GalCat/SRD-Y1/NLA/'
pathTT='/global/homes/j/jharno/IA-infusion/SkySim5000/GalCat/SRD-Y1/TT/'
for tomo in range(1,2):
    fname_in_NLA='galcat_skysim5000_AIAp1_tomo'+str(tomo)+'.dat'
    fname_in_TT='galcat_skysim5000_C2p1_tomo'+str(tomo)+'.dat'
    GalCat_NLA = np.loadtxt(pathNLA+fname_in_NLA)
    GalCat_TT = np.loadtxt(pathTT+fname_in_TT)
    
    #hp.mollview()
    #hp.projscatter(GalCat[:,0],GalCat[:,1], lonlat=True)
    #plt.show()
    
    #hp.cartview(lonra=lonra, latra=latra,
    #            nest=False,
    #            title=" ",
    #            norm=None, unit=None)
    #hp.projscatter(GalCat[:,0],GalCat[:,1],lonlat=True,marker=(5, 2),c='tab:orange',alpha=0.3)
    #plt.show()
    
    #ra dec z g1 g2 weight delta e_obs_1 e_obs_2 e_obs_no_noise_1 e_obs_no_noise_2 e_IA_TATT_1 e_IA_TATT_2

# %%
bin_edges=np.linspace(-0.02-0.001,0.02+0.001,201) 
bin_mids=(bin_edges[1:]+bin_edges[:-1])/2
PDF_g1, _ = np.histogram(GalCat_NLA[:,3], bin_edges, density=False)
PDF_g2, _ = np.histogram(GalCat_NLA[:,4], bin_edges, density=False)

PDF_eIA1_NLA, _ = np.histogram(GalCat_NLA[:,11], bin_edges, density=False)
PDF_eIA2_NLA, _ = np.histogram(GalCat_NLA[:,12]/2, bin_edges, density=False)
PDF_eIA1_TT, _ = np.histogram(GalCat_TT[:,11], bin_edges, density=False)
PDF_eIA2_TT, _ = np.histogram(GalCat_TT[:,12]/2, bin_edges, density=False)

#plt.plot(bin_mids, PDF_g1.T)
#plt.plot(bin_mids, PDF_g2.T)
plt.plot(bin_mids, PDF_eIA1_NLA.T)
plt.plot(bin_mids, PDF_eIA2_NLA.T)
plt.plot(bin_mids, PDF_eIA1_TT.T)
plt.plot(bin_mids, PDF_eIA2_TT.T)
#plt.fill_between(binMid, PDF - PDF_standard_deviation, PDF + PDF_standard_deviation, alpha=0.5)
plt.xlim(-0.005,0.005)

#plt.semilogy()
plt.show()

# %%
# Visualise the mask file
hpmap_weight = hp.fitsfunc.read_map('../../FullSky_weight.fits', field=0,nest=False, partial=False, hdu=1, h=False, verbose=True, memmap=True)
#
# masking - not really necessary here, but just in case it is useful for something else.
unmask = np.where(hpmap_weight > 0)[0]


NSIDE=8192
pixel_area_arcmin2 = hp.pixelfunc.nside2pixarea(nside=NSIDE)*(180*60/np.pi)**2
octant_area_arcmin2 = sum(unmask)*pixel_area_arcmin2
# Out:
# /tmp/ipykernel_90303/157496496.py:2: HealpyDeprecationWarning: "verbose" was deprecated in version 1.15.0 and will be removed in a future version.
#   hpmap_weight = hp.fitsfunc.read_map('../..//FullSky_weight.fits', field=0,nest=False, partial=False, hdu=1, h=False, verbose=True, memmap=True)

# %%
ls ../../
# Out:
# density/                  GalCat/       README_mass_sheets.txt  tidalfield/
# FullSky_weight_4096.fits  kappa/        shear/                  tools/
# FullSky_weight.fits       mass_sheets@  SkySimReader.ipynb

# %%
g1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 g1
#
# NameError: name 'g1' is not defined

# %%
SDG
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 SDG
#
# NameError: name 'SDG' is not defined

# %%
filename = '/pscratch/sd/a/avijit97/BCM/HACC/params_dependencies/full_lightcone/Mc/2e14/nshells_51/nshells_51_imap_{}/baryonified_shells_v11.h5'.format(27)
#/pscratch/sd/a/avijit97/BCM/HACC/params_dependencies/full_lightcone/Mc/2e14/nshells_51/
dmo = True

with h5py.File(filename,'r') as f:
    #print('h5py file fields:',f.keys())
    nobaryon_shells = np.array(f['nobaryon_shells'])
    diff_shells = np.array(f['diff_shells'])
    #baryon_shells = nobaryon_shells+diff_shells

if(dmo):
    hpmap_density=nobaryon_shells
else:
    hpmap_density=nobaryon_shells+diff_shells

# %%
lonra = [0, 8]
latra = [0, 4]
hp.cartview(hpmap_density[0], lonra=lonra, latra=latra,
            nest=False,
            title=" ",
            norm=None, unit=None)

# %%
np.shape(hpmap_density[0])
# Out:
# (805306368,)

# %%
12*8192**2
# Out:
# 805306368

# %%
import numpy as np
tmpfile = np.load("/pscratch/sd/j/jmena/HOS_Sims/HACC150_3/shells_z51_subsampledensitymax1.5_nside8192/shell_hacc_seed0_shell_info.npy")

# %%
for i in range(51): print(tmpfile[i][0], tmpfile[i][3])
# Out:
# 0 0.008024072216650024
# 1 0.024464831804281273
# 2 0.041450777202072686
# 3 0.05900948366701808
# 4 0.07717041800643099
# 5 0.09596510359869148
# 6 0.11542730299667059
# 7 0.13559322033898313
# 8 0.15650172612197943
# 9 0.17819460726846414
# 10 0.20071684587813632
# 11 0.22411693057247262
# 12 0.24844720496894435
# 13 0.2737642585551332
# 14 0.3001293661060802
# 15 0.3276089828269486
# 16 0.35627530364372473
# 17 0.38620689655172424
# 18 0.41748942172073367
# 19 0.4502164502164505
# 20 0.48449039881831646
# 21 0.5204236006051437
# 22 0.558139534883721
# 23 0.5977742448330685
# 24 0.6394779771615009
# 25 0.683417085427136
# 26 0.7297762478485372
# 27 0.7787610619469028
# 28 0.8306010928961749
# 29 0.8855534709193247
# 30 0.9439071566731143
# 31 1.0059880239520962
# 32 1.0721649484536084
# 33 1.1428571428571432
# 34 1.2185430463576163
# 35 1.2997711670480552
# 36 1.3871733966745845
# 37 1.4814814814814818
# 38 1.5835475578406175
# 39 1.6943699731903488
# 40 1.8151260504201683
# 41 1.9472140762463344
# 42 2.0923076923076924
# 43 2.2524271844660197
# 44 2.4300341296928334
# 45 2.6281588447653434
# 46 2.8505747126436787
# 47 3.1020408163265314
# 48 3.388646288209607
# 49 3.718309859154929
# 50 4.101522842639594

# %%
15 * 1300 * 64 / 60 *256 / 1e6
# Out:
# 3.6864

# %%
64/60
# Out:
# 1.0666666666666667

# %%
path_in = '/global/cfs/cdirs/m5099/FS2/'

zfile = np.loadtxt(path_in+"steps.fs2.ssv",skiprows=1)
#This is structured as:
# step dist_min dist_max dist_median z_median a_median, distances in Mpc/h
#comoving_edges = np.hstack([np.array(zfile[:,1]),np.array(zfile[:,2])[-1]])/cosmo.h # 

#zfile=np.loadtxt("z2ts_HACCY1_51.txt",delimiter=' ')
snaplist = zfile[:,0].astype(int)
zlist=zfile[:,4]

# %%
# Out:
# array([3.92646299, 3.73618449, 3.56294863, 3.4044349 , 3.25873144,
#        3.12425334, 2.99967233, 2.88386822, 2.77588362, 2.67490426,
#        2.58022289, 2.49122915, 2.40739156, 2.32824249, 2.25337175,
#        2.18241688, 2.11505573, 2.05100222, 1.98999892, 1.93181684,
#        1.87624928, 1.82311062, 1.77223109, 1.72345681, 1.67665062,
#        1.63168493, 1.58844273, 1.54681847, 1.50671607, 1.46804378,
#        1.43072122, 1.39467129, 1.35982417, 1.32611326, 1.2934802 ,
#        1.26186782, 1.23122512, 1.20150226, 1.17265351, 1.14463834,
#        1.11741627, 1.09095098, 1.06520619, 1.04015178, 1.01575463,
#        0.99198807, 0.96882415, 0.9462377 , 0.92420461, 0.90270221,
#        0.88170911, 0.86120521, 0.84117131, 0.82158921, 0.80244186,
#        0.78371284, 0.76538688, 0.7474491 , 0.72988567, 0.7126833 ,
#        0.69582928, 0.67931176, 0.6631191 , 0.64724047, 0.63166535,
#        0.61638387, 0.60138644, 0.58666411, 0.57220812, 0.55801014,
#        0.54406215, 0.53035663, 0.51688628, 0.5036441 , 0.49062333,
#        0.47781757, 0.46522057, 0.45282647, 0.44062951, 0.42862425,
#        0.41680536, 0.40516789, 0.39370684, 0.38241757, 0.37129557,
#        0.36033633, 0.34953595, 0.33889014, 0.32839507, 0.31804688,
#        0.30784216, 0.29777714, 0.28784864, 0.27805327, 0.26838795,
#        0.25884953, 0.24943503, 0.24014178, 0.23096681, 0.22190758,
#        0.21296142, 0.20412586, 0.19539837, 0.18677678, 0.17825874,
#        0.16984191, 0.16152434, 0.15330388, 0.14517849, 0.13714614,
#        0.12920516, 0.12135344, 0.11358943, 0.10591119, 0.09831719,
#        0.0908057 , 0.08337518, 0.07602405, 0.06875083, 0.06155403,
#        0.05443225, 0.0473841 , 0.04040823, 0.03350334, 0.02666817,
#        0.01990139, 0.01320199, 0.00656848])
